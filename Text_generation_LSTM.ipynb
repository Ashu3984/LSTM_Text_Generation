# %%
import pandas as pd
import numpy as np

import tensorflow as tf
# from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense,Dropout
from keras.preprocessing.text import Tokenizer
import keras.utils as ku
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
import re
import string

# %%
df = pd.read_csv('/content/transcripts.csv.zip')

# %%
df.shape
# Out:
# (2467, 2)

# %%
fraction = 0.03
df = df.sample(frac=fraction, random_state=42)

# %%
df.shape
# Out:
# (74, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 1711 to 1173
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   transcript  74 non-null     object
#  1   url         74 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
df['transcript'] = df['transcript'].astype(str)

# %%
# text=''
# for i in df['transcript']:
#     text=text + i

# %%
# train_text = text[:500000]

# %%
# cleaned_text = []
# for i in train_text.split():
#     i = i.lower()
#     i = re.sub('https?://\S+|www\.\S+', '', i)

#     #now stemming all the words that are not stop words
#     # i = i.split()
#     # review = [ps.stem(word) for word in review if not word in stop_words]
#     # review = ' '.join(review)
#     i = re.sub('\\W', ' ', i)
#     i = re.sub('\n', '', i)
#     i = re.sub(' +', ' ', i)
#     i = re.sub('^ ', '', i)
#     i = re.sub(' $', '', i)
#     cleaned_text.append(i)

# %%
# train_text[:500]

# %%
def clean(text):
    return re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>",text)

# %%
df['transcript'] = df['transcript'].apply(lambda x:clean(x))

# %%
df['transcript']
# Out:
# 1711    I would like to share with you a new model of ...
# 1557    Mobility in developing world cities is a very ...
# 1870    I dedicated the past two years to understandin...
# 1703    When I was preparing for this talk, I went to ...
# 1857    We are built out of very small stuff, and we a...
#                               ...
# 1851    Today I'm going to speak to you about the last...
# 296     What I want to tell you about today is how I s...
# 435     This is a sculpture I made, which is a way of,...
# 1993    Interpreter: Piano, "p," is my favorite musica...
# 1173                                     ()()()()()()()()
# Name: transcript, Length: 74, dtype: object

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def clean_text(txt):
    return txt.translate(str.maketrans('', '', string.punctuation))

# %%
df['transcript'] = df['transcript'].apply(lambda x:clean_text(x))

# %%
df['transcript']
# Out:
# 1711    I would like to share with you a new model of ...
# 1557    Mobility in developing world cities is a very ...
# 1870    I dedicated the past two years to understandin...
# 1703    When I was preparing for this talk I went to s...
# 1857    We are built out of very small stuff and we ar...
#                               ...
# 1851    Today Im going to speak to you about the last ...
# 296     What I want to tell you about today is how I s...
# 435     This is a sculpture I made which is a way of k...
# 1993    Interpreter Piano p is my favorite musical sym...
# 1173
# Name: transcript, Length: 74, dtype: object

# %%
token = Tokenizer()
token.fit_on_texts(df['transcript'])

# %%
token.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'to': 3,
#  'of': 4,
#  'a': 5,
#  'that': 6,
#  'in': 7,
#  'i': 8,
#  'is': 9,
#  'you': 10,
#  'we': 11,
#  'it': 12,
#  'this': 13,
#  'was': 14,
#  'for': 15,
#  'so': 16,
#  'are': 17,
#  'have': 18,
#  'on': 19,
#  'they': 20,
#  'with': 21,
#  'its': 22,
#  'can': 23,
#  'what': 24,
#  'but': 25,
#  '—': 26,
#  'about': 27,
#  'be': 28,
#  'at': 29,
#  'do': 30,
#  'as': 31,
#  'not': 32,
#  'all': 33,
#  'my': 34,
#  'were': 35,
#  'people': 36,
#  'from': 37,
#  'there': 38,
#  'one': 39,
#  'if': 40,
#  'like': 41,
#  'our': 42,
#  'or': 43,
#  'just': 44,
#  'these': 45,
#  'me': 46,
#  'very': 47,
#  'he': 48,
#  'had': 49,
#  'because': 50,
#  'an': 51,
#  'now': 52,
#  'out': 53,
#  'how': 54,
#  'when': 55,
#  'thats': 56,
#  'more': 57,
#  'see': 58,
#  'which': 59,
#  'by': 60,
#  'them': 61,
#  'up': 62,
#  'know': 63,
#  'their': 64,
#  'would': 65,
#  'going': 66,
#  'think': 67,
#  'really': 68,
#  'your': 69,
#  'years': 70,
#  'who': 71,
#  'us': 72,
#  'get': 73,
#  'time': 74,
#  'some': 75,
#  'world': 76,
#  'here': 77,
#  'then': 78,
#  'has': 79,
#  'said': 80,
#  'little': 81,
#  'dont': 82,
#  'im': 83,
#  'she': 84,
#  'been': 85,
#  'her': 86,
#  'will': 87,
#  'could': 88,
#  'into': 89,
#  'well': 90,
#  'those': 91,
#  'go': 92,
#  'no': 93,
#  'something': 94,
#  'make': 95,
#  'things': 96,
#  'way': 97,
#  'want': 98,
#  'over': 99,
#  'two': 100,
#  'right': 101,
#  'where': 102,
#  'other': 103,
#  'much': 104,
#  'than': 105,
#  'first': 106,
#  'thing': 107,
#  'need': 108,
#  'got': 109,
#  'youre': 110,
#  'his': 111,
#  'most': 112,
#  'actually': 113,
#  'say': 114,
#  'ive': 115,
#  'around': 116,
#  'look': 117,
#  'why': 118,
#  'did': 119,
#  'theres': 120,
#  'back': 121,
#  'take': 122,
#  'only': 123,
#  'new': 124,
#  'also': 125,
#  'water': 126,
#  'every': 127,
#  'different': 128,
#  'theyre': 129,
#  'even': 130,
#  'good': 131,
#  'kind': 132,
#  'life': 133,
#  'many': 134,
#  'lot': 135,
#  'through': 136,
#  'same': 137,
#  'work': 138,
#  'come': 139,
#  'use': 140,
#  'down': 141,
#  'today': 142,
#  'three': 143,
#  'weve': 144,
#  'put': 145,
#  'any': 146,
#  'change': 147,
#  'being': 148,
#  'give': 149,
#  'last': 150,
#  'day': 151,
#  'feel': 152,
#  'ago': 153,
#  'never': 154,
#  'talk': 155,
#  'didnt': 156,
#  'problem': 157,
#  'called': 158,
#  'percent': 159,
#  'started': 160,
#  'still': 161,
#  'doing': 162,
#  'tell': 163,
#  'great': 164,
#  'fact': 165,
#  'show': 166,
#  'able': 167,
#  'after': 168,
#  'each': 169,
#  'next': 170,
#  'should': 171,
#  'again': 172,
#  'before': 173,
#  'big': 174,
#  'might': 175,
#  'part': 176,
#  'human': 177,
#  'cant': 178,
#  'together': 179,
#  'came': 180,
#  'find': 181,
#  'women': 182,
#  'made': 183,
#  '♫': 184,
#  'idea': 185,
#  'story': 186,
#  'long': 187,
#  'away': 188,
#  'own': 189,
#  'children': 190,
#  'few': 191,
#  'live': 192,
#  'let': 193,
#  'does': 194,
#  'better': 195,
#  'example': 196,
#  'four': 197,
#  'went': 198,
#  'robot': 199,
#  'help': 200,
#  'year': 201,
#  'start': 202,
#  'another': 203,
#  'cities': 204,
#  '♫♫': 205,
#  'him': 206,
#  'important': 207,
#  'believe': 208,
#  'question': 209,
#  'bit': 210,
#  'wanted': 211,
#  'looking': 212,
#  'men': 213,
#  'lets': 214,
#  'hes': 215,
#  'whats': 216,
#  'place': 217,
#  'doesnt': 218,
#  'using': 219,
#  'end': 220,
#  'means': 221,
#  'heres': 222,
#  'whole': 223,
#  'between': 224,
#  'always': 225,
#  'number': 226,
#  'too': 227,
#  'thought': 228,
#  'data': 229,
#  'sort': 230,
#  'robots': 231,
#  'done': 232,
#  'lives': 233,
#  'old': 234,
#  'building': 235,
#  'less': 236,
#  'best': 237,
#  'may': 238,
#  'used': 239,
#  'five': 240,
#  'happened': 241,
#  'money': 242,
#  'system': 243,
#  'future': 244,
#  'such': 245,
#  'maybe': 246,
#  'found': 247,
#  'science': 248,
#  'anything': 249,
#  'brain': 250,
#  'side': 251,
#  'second': 252,
#  'thinking': 253,
#  'off': 254,
#  'yet': 255,
#  'create': 256,
#  'build': 257,
#  'mean': 258,
#  'understand': 259,
#  '10': 260,
#  'death': 261,
#  'thank': 262,
#  'hand': 263,
#  'love': 264,
#  'already': 265,
#  'days': 266,
#  'energy': 267,
#  'million': 268,
#  'top': 269,
#  'reality': 270,
#  'become': 271,
#  'interesting': 272,
#  'point': 273,
#  'community': 274,
#  'problems': 275,
#  'city': 276,
#  'ever': 277,
#  'learn': 278,
#  'sense': 279,
#  'asked': 280,
#  'room': 281,
#  'seen': 282,
#  'looked': 283,
#  'internet': 284,
#  'course': 285,
#  'youve': 286,
#  'left': 287,
#  'home': 288,
#  'everything': 289,
#  'bad': 290,
#  'man': 291,
#  'school': 292,
#  'countries': 293,
#  'sometimes': 294,
#  'possible': 295,
#  'talking': 296,
#  'real': 297,
#  'social': 298,
#  'nothing': 299,
#  'am': 300,
#  'looks': 301,
#  'control': 302,
#  'care': 303,
#  'patients': 304,
#  'process': 305,
#  'solve': 306,
#  'pretty': 307,
#  'da': 308,
#  'probably': 309,
#  'comes': 310,
#  'open': 311,
#  'call': 312,
#  'times': 313,
#  'took': 314,
#  'person': 315,
#  'trying': 316,
#  'medical': 317,
#  'getting': 318,
#  'god': 319,
#  'enough': 320,
#  'says': 321,
#  'coming': 322,
#  'technology': 323,
#  'public': 324,
#  'hope': 325,
#  'hard': 326,
#  'face': 327,
#  'family': 328,
#  'living': 329,
#  'set': 330,
#  'sound': 331,
#  'small': 332,
#  'kids': 333,
#  'months': 334,
#  'states': 335,
#  'making': 336,
#  'quite': 337,
#  'heard': 338,
#  'working': 339,
#  'global': 340,
#  'feeling': 341,
#  'stuff': 342,
#  'wasnt': 343,
#  'dollars': 344,
#  'picture': 345,
#  'try': 346,
#  'sand': 347,
#  'everybody': 348,
#  'space': 349,
#  'run': 350,
#  'couple': 351,
#  'imagine': 352,
#  'sure': 353,
#  'inside': 354,
#  'oh': 355,
#  'turns': 356,
#  'until': 357,
#  'once': 358,
#  '20': 359,
#  'without': 360,
#  '100': 361,
#  'computer': 362,
#  'ask': 363,
#  'taking': 364,
#  'works': 365,
#  'makes': 366,
#  'often': 367,
#  'whether': 368,
#  'remember': 369,
#  'half': 370,
#  'turn': 371,
#  'house': 372,
#  'goes': 373,
#  'education': 374,
#  'woman': 375,
#  'reason': 376,
#  'power': 377,
#  'both': 378,
#  'completely': 379,
#  'later': 380,
#  'saw': 381,
#  'research': 382,
#  'across': 383,
#  'yeah': 384,
#  'groups': 385,
#  'buildings': 386,
#  'model': 387,
#  'cannot': 388,
#  'under': 389,
#  'move': 390,
#  'simple': 391,
#  'far': 392,
#  'saying': 393,
#  'mountain': 394,
#  'words': 395,
#  'shes': 396,
#  'ill': 397,
#  'answer': 398,
#  'climate': 399,
#  'business': 400,
#  'while': 401,
#  'play': 402,
#  'someone': 403,
#  'air': 404,
#  'language': 405,
#  'within': 406,
#  'marijuana': 407,
#  'guys': 408,
#  'amazing': 409,
#  'young': 410,
#  'weeks': 411,
#  'hear': 412,
#  'since': 413,
#  'word': 414,
#  'group': 415,
#  'mind': 416,
#  'arm': 417,
#  'higher': 418,
#  'gave': 419,
#  'places': 420,
#  'wrong': 421,
#  'themselves': 422,
#  'choice': 423,
#  'experience': 424,
#  'stories': 425,
#  'food': 426,
#  'outside': 427,
#  'share': 428,
#  'ways': 429,
#  'knew': 430,
#  'third': 431,
#  'others': 432,
#  'health': 433,
#  'rather': 434,
#  'united': 435,
#  'myself': 436,
#  'told': 437,
#  'gender': 438,
#  'high': 439,
#  'leave': 440,
#  'country': 441,
#  'students': 442,
#  'attention': 443,
#  'matter': 444,
#  'poor': 445,
#  'democracy': 446,
#  'built': 447,
#  'yes': 448,
#  'news': 449,
#  'front': 450,
#  'okay': 451,
#  'seeing': 452,
#  'project': 453,
#  'job': 454,
#  'true': 455,
#  'political': 456,
#  'book': 457,
#  'body': 458,
#  'onto': 459,
#  'learned': 460,
#  'basically': 461,
#  'huge': 462,
#  'exactly': 463,
#  'exist': 464,
#  'english': 465,
#  'guy': 466,
#  'friends': 467,
#  'read': 468,
#  'information': 469,
#  'happens': 470,
#  'hours': 471,
#  'gets': 472,
#  'six': 473,
#  'having': 474,
#  'isnt': 475,
#  'id': 476,
#  'somebody': 477,
#  'close': 478,
#  'girl': 479,
#  'size': 480,
#  'architecture': 481,
#  'became': 482,
#  'almost': 483,
#  '30': 484,
#  'kinds': 485,
#  'bring': 486,
#  'created': 487,
#  'single': 488,
#  'state': 489,
#  'happen': 490,
#  'instead': 491,
#  'image': 492,
#  'needed': 493,
#  'couldnt': 494,
#  'eyes': 495,
#  'thousands': 496,
#  'case': 497,
#  'sitting': 498,
#  'local': 499,
#  'moon': 500,
#  'everyone': 501,
#  'waste': 502,
#  'war': 503,
#  'society': 504,
#  'video': 505,
#  'history': 506,
#  'land': 507,
#  'middle': 508,
#  'modern': 509,
#  'felt': 510,
#  'youll': 511,
#  'earth': 512,
#  'week': 513,
#  'must': 514,
#  'cars': 515,
#  'ones': 516,
#  'easy': 517,
#  'stop': 518,
#  'given': 519,
#  'pictures': 520,
#  'likely': 521,
#  'line': 522,
#  'study': 523,
#  'based': 524,
#  'moment': 525,
#  'universe': 526,
#  'keep': 527,
#  'physical': 528,
#  'ok': 529,
#  'eye': 530,
#  'playing': 531,
#  'aid': 532,
#  'difficult': 533,
#  'order': 534,
#  'moving': 535,
#  '50': 536,
#  'child': 537,
#  'changed': 538,
#  'past': 539,
#  'else': 540,
#  'team': 541,
#  'field': 542,
#  'though': 543,
#  'giving': 544,
#  'spent': 545,
#  'support': 546,
#  'relationship': 547,
#  'hands': 548,
#  'feet': 549,
#  'age': 550,
#  'cancer': 551,
#  'itself': 552,
#  'millions': 553,
#  'during': 554,
#  'board': 555,
#  'learning': 556,
#  'developing': 557,
#  'car': 558,
#  'beautiful': 559,
#  'walk': 560,
#  'finally': 561,
#  'yourself': 562,
#  'wrote': 563,
#  'decided': 564,
#  'choose': 565,
#  'realized': 566,
#  'whatever': 567,
#  'figure': 568,
#  'quickly': 569,
#  'miles': 570,
#  'white': 571,
#  'design': 572,
#  'alzheimers': 573,
#  'turned': 574,
#  'university': 575,
#  'challenge': 576,
#  'conflict': 577,
#  'recently': 578,
#  'step': 579,
#  'telling': 580,
#  'camera': 581,
#  'nature': 582,
#  'name': 583,
#  'nice': 584,
#  'seven': 585,
#  'questions': 586,
#  'perhaps': 587,
#  'generation': 588,
#  'species': 589,
#  'doaa': 590,
#  'night': 591,
#  'large': 592,
#  'equality': 593,
#  'music': 594,
#  'minutes': 595,
#  'speak': 596,
#  'towards': 597,
#  'success': 598,
#  'ourselves': 599,
#  'signals': 600,
#  'bigger': 601,
#  'billion': 602,
#  'theory': 603,
#  'baby': 604,
#  'media': 605,
#  'humans': 606,
#  'south': 607,
#  '40': 608,
#  'shows': 609,
#  'difference': 610,
#  'black': 611,
#  '15': 612,
#  'london': 613,
#  'watch': 614,
#  'head': 615,
#  'alone': 616,
#  'journey': 617,
#  'individual': 618,
#  'amount': 619,
#  'along': 620,
#  'takes': 621,
#  'key': 622,
#  'mother': 623,
#  'taken': 624,
#  'deep': 625,
#  'particular': 626,
#  'deal': 627,
#  'eight': 628,
#  'happening': 629,
#  'century': 630,
#  'please': 631,
#  'parents': 632,
#  'fear': 633,
#  'killed': 634,
#  'choices': 635,
#  'paper': 636,
#  'crisis': 637,
#  'son': 638,
#  'view': 639,
#  'common': 640,
#  'animals': 641,
#  'experiment': 642,
#  'save': 643,
#  'tiny': 644,
#  'theyve': 645,
#  'ted': 646,
#  'known': 647,
#  'gives': 648,
#  'lose': 649,
#  'clock': 650,
#  '25': 651,
#  'laws': 652,
#  'center': 653,
#  'cybercriminals': 654,
#  'boat': 655,
#  'existence': 656,
#  'penalty': 657,
#  'late': 658,
#  'changes': 659,
#  'urban': 660,
#  'friend': 661,
#  'met': 662,
#  'blind': 663,
#  'environment': 664,
#  'longer': 665,
#  'level': 666,
#  'certain': 667,
#  'families': 668,
#  'either': 669,
#  'planet': 670,
#  'special': 671,
#  'named': 672,
#  'morning': 673,
#  'ready': 674,
#  'boy': 675,
#  'web': 676,
#  'heart': 677,
#  'national': 678,
#  'red': 679,
#  'afghanistan': 680,
#  'brought': 681,
#  'clean': 682,
#  'happy': 683,
#  'security': 684,
#  'behind': 685,
#  'perfect': 686,
#  'soon': 687,
#  'wont': 688,
#  'chance': 689,
#  'reasons': 690,
#  'putting': 691,
#  'quality': 692,
#  'powerful': 693,
#  'growing': 694,
#  'sorts': 695,
#  'risks': 696,
#  'knowledge': 697,
#  'act': 698,
#  'light': 699,
#  'least': 700,
#  'meaning': 701,
#  'lots': 702,
#  'starting': 703,
#  'disease': 704,
#  'numbers': 705,
#  'approach': 706,
#  'sit': 707,
#  'form': 708,
#  'cells': 709,
#  'blue': 710,
#  'absolutely': 711,
#  'microscopic': 712,
#  'fall': 713,
#  'arms': 714,
#  'military': 715,
#  'photo': 716,
#  'lung': 717,
#  'pick': 718,
#  'meet': 719,
#  'student': 720,
#  'free': 721,
#  'entire': 722,
#  'population': 723,
#  'market': 724,
#  '80': 725,
#  'homes': 726,
#  'hundreds': 727,
#  'everywhere': 728,
#  'becomes': 729,
#  'freedom': 730,
#  'among': 731,
#  'spend': 732,
#  'beginning': 733,
#  'valley': 734,
#  'table': 735,
#  'several': 736,
#  'complicated': 737,
#  'full': 738,
#  'international': 739,
#  'visual': 740,
#  'david': 741,
#  'solutions': 742,
#  'site': 743,
#  'forward': 744,
#  'creating': 745,
#  'relationships': 746,
#  'listen': 747,
#  'map': 748,
#  'ground': 749,
#  'literally': 750,
#  'gone': 751,
#  'starts': 752,
#  'obviously': 753,
#  'voice': 754,
#  'lost': 755,
#  'sun': 756,
#  'daughter': 757,
#  'father': 758,
#  'foot': 759,
#  'park': 760,
#  'died': 761,
#  'photos': 762,
#  'bassem': 763,
#  'asl': 764,
#  'worked': 765,
#  'pay': 766,
#  'rest': 767,
#  'test': 768,
#  'needs': 769,
#  'class': 770,
#  'solution': 771,
#  'projects': 772,
#  'further': 773,
#  'impact': 774,
#  'wait': 775,
#  'wouldnt': 776,
#  'california': 777,
#  'audience': 778,
#  'against': 779,
#  '200': 780,
#  'patterns': 781,
#  'translate': 782,
#  'skin': 783,
#  'station': 784,
#  'systems': 785,
#  'short': 786,
#  'talked': 787,
#  'supposed': 788,
#  'personal': 789,
#  'grew': 790,
#  'cause': 791,
#  'cool': 792,
#  'guess': 793,
#  'trust': 794,
#  'forms': 795,
#  'area': 796,
#  'notice': 797,
#  'break': 798,
#  'record': 799,
#  'knows': 800,
#  'worlds': 801,
#  'north': 802,
#  'doctor': 803,
#  'iraq': 804,
#  'conflicts': 805,
#  'hospital': 806,
#  'supply': 807,
#  'dream': 808,
#  'financial': 809,
#  'parts': 810,
#  'stopped': 811,
#  'buy': 812,
#  'resources': 813,
#  'per': 814,
#  'scale': 815,
#  'terms': 816,
#  'government': 817,
#  'however': 818,
#  'especially': 819,
#  'green': 820,
#  'respect': 821,
#  'anywhere': 822,
#  'york': 823,
#  'risk': 824,
#  'following': 825,
#  'street': 826,
#  'understanding': 827,
#  'wants': 828,
#  'moved': 829,
#  'stay': 830,
#  'position': 831,
#  'damage': 832,
#  'havent': 833,
#  'lab': 834,
#  'equipment': 835,
#  'forth': 836,
#  'led': 837,
#  'anyone': 838,
#  'development': 839,
#  'serious': 840,
#  'wikipedia': 841,
#  'tried': 842,
#  'mine': 843,
#  'art': 844,
#  'early': 845,
#  'favorite': 846,
#  'surface': 847,
#  'die': 848,
#  'program': 849,
#  'drive': 850,
#  'piece': 851,
#  'snow': 852,
#  'issues': 853,
#  'behavior': 854,
#  'dangerous': 855,
#  'chapter': 856,
#  'tricks': 857,
#  'romo': 858,
#  'civil': 859,
#  'nearly': 860,
#  'opportunity': 861,
#  'expensive': 862,
#  'pass': 863,
#  'stand': 864,
#  'positive': 865,
#  'basic': 866,
#  'advanced': 867,
#  'economy': 868,
#  'companies': 869,
#  'indeed': 870,
#  'natural': 871,
#  'dreams': 872,
#  'legal': 873,
#  'seconds': 874,
#  'speaking': 875,
#  'brains': 876,
#  'economic': 877,
#  'nerve': 878,
#  'essentially': 879,
#  'page': 880,
#  'tools': 881,
#  'gotten': 882,
#  'website': 883,
#  'bits': 884,
#  'expect': 885,
#  'communities': 886,
#  'clear': 887,
#  'central': 888,
#  'scientific': 889,
#  'challenges': 890,
#  'older': 891,
#  'shown': 892,
#  'mountains': 893,
#  'pole': 894,
#  'solar': 895,
#  'earlier': 896,
#  'rate': 897,
#  'bunch': 898,
#  'san': 899,
#  'pressure': 900,
#  'eventually': 901,
#  'period': 902,
#  'recognize': 903,
#  'speaker': 904,
#  'conversation': 905,
#  'europe': 906,
#  'police': 907,
#  'restaurant': 908,
#  'chicken': 909,
#  'individuals': 910,
#  'focus': 911,
#  'continue': 912,
#  'poverty': 913,
#  'africa': 914,
#  'biggest': 915,
#  'simply': 916,
#  'governments': 917,
#  'fast': 918,
#  'direction': 919,
#  'except': 920,
#  'fly': 921,
#  'unless': 922,
#  'grow': 923,
#  'seem': 924,
#  'growth': 925,
#  'harder': 926,
#  'goals': 927,
#  'successful': 928,
#  'famous': 929,
#  'cell': 930,
#  'experienced': 931,
#  'report': 932,
#  'nine': 933,
#  'standing': 934,
#  'developed': 935,
#  'note': 936,
#  'major': 937,
#  'ideas': 938,
#  'allow': 939,
#  'mess': 940,
#  'push': 941,
#  'town': 942,
#  'hour': 943,
#  'structure': 944,
#  'violence': 945,
#  'cymatics': 946,
#  'genes': 947,
#  'flow': 948,
#  'robin': 949,
#  'sea': 950,
#  'ice': 951,
#  'similar': 952,
#  'connect': 953,
#  'chest': 954,
#  'office': 955,
#  'books': 956,
#  'himself': 957,
#  'helped': 958,
#  'company': 959,
#  'worth': 960,
#  'bottom': 961,
#  'transformations': 962,
#  'carbon': 963,
#  'decade': 964,
#  'sustainable': 965,
#  'ended': 966,
#  'agree': 967,
#  'embodied': 968,
#  'roughness': 969,
#  'potential': 970,
#  'access': 971,
#  'average': 972,
#  'including': 973,
#  'interact': 974,
#  'village': 975,
#  'studies': 976,
#  'necessary': 977,
#  'vision': 978,
#  'despite': 979,
#  'spaces': 980,
#  'democratic': 981,
#  'equal': 982,
#  'road': 983,
#  'normal': 984,
#  'seems': 985,
#  'lines': 986,
#  'wonderful': 987,
#  'low': 988,
#  'america': 989,
#  'decide': 990,
#  'peak': 991,
#  'hundred': 992,
#  'increase': 993,
#  'usually': 994,
#  'closer': 995,
#  'totally': 996,
#  'turning': 997,
#  'writing': 998,
#  'theyd': 999,
#  'healthcare': 1000,
#  ...}

# %%
len(token.word_index)
# Out:
# 12152

# %%
len(token.word_counts)
# Out:
# 12152

# %%
token.document_count
# Out:
# 74

# %%
sequence = token.texts_to_sequences(df['transcript'])

# %%
sequence
# Out:
# [[8,
#   65,
#   41,
#   3,
#   428,
#   21,
#   10,
#   5,
#   124,
#   387,
#   4,
#   418,
#   374,
#   5,
#   387,
#   6,
#   358,
#   3949,
#   23,
#   5789,
#   1,
#   1675,
#   1501,
#   4,
#   553,
#   4,
#   1150,
#   2,
#   3067,
#   910,
#   6,
#   1222,
#   65,
#   28,
#   287,
#   685,
#   117,
#   29,
#   1,
#   76,
#   718,
#   5,
#   217,
#   2,
#   911,
#   19,
#   12,
#   10,
#   87,
#   181,
#   606,
#   3068,
#   418,
#   374,
#   214,
#   719,
#   75,
#   4,
#   5790,
#   2535,
#   14,
#   1151,
#   7,
#   5791,
#   3,
#   5,
#   328,
#   4,
#   359,
#   190,
#   554,
#   1,
#   859,
#   503,
#   48,
#   2,
#   111,
#   328,
#   35,
#   2170,
#   3,
#   3069,
#   3,
#   5792,
#   38,
#   7,
#   5793,
#   4,
#   111,
#   1152,
#   48,
#   5794,
#   439,
#   292,
#   21,
#   860,
#   686,
#   3950,
#   48,
#   211,
#   3,
#   912,
#   3,
#   418,
#   374,
#   25,
#   1347,
#   3,
#   111,
#   328,
#   329,
#   19,
#   1,
#   913,
#   522,
#   48,
#   14,
#   687,
#   1348,
#   3,
#   607,
#   914,
#   3,
#   138,
#   2,
#   1502,
#   121,
#   242,
#   3,
#   1349,
#   111,
#   328,
#   2535,
#   154,
#   419,
#   62,
#   111,
#   808,
#   4,
#   418,
#   374,
#   658,
#   29,
#   591,
#   168,
#   138,
#   48,
#   5795,
#   1,
#   2171,
#   212,
#   15,
#   429,
#   3,
#   5796,
#   1891,
#   1891,
#   9,
#   37,
#   1676,
#   86,
#   632,
#   156,
#   92,
#   3,
#   1503,
#   2,
#   3951,
#   119,
#   146,
#   4,
#   86,
#   3070,
#   1891,
#   79,
#   765,
#   33,
#   86,
#   133,
#   1892,
#   5797,
#   2536,
#   1677,
#   1153,
#   3,
#   1153,
#   1893,
#   4,
#   1,
#   1504,
#   808,
#   5,
#   808,
#   6,
#   44,
#   688,
#   28,
#   1223,
#   360,
#   418,
#   374,
#   25,
#   1891,
#   218,
#   18,
#   1,
#   2537,
#   15,
#   418,
#   374,
#   84,
#   178,
#   766,
#   1,
#   3952,
#   3951,
#   88,
#   84,
#   440,
#   5798,
#   2538,
#   2538,
#   9,
#   37,
#   2539,
#   215,
#   1894,
#   5799,
#   1,
#   5800,
#   633,
#   2,
#   5801,
#   5802,
#   19,
#   111,
#   441,
#   215,
#   5,
#   174,
#   5803,
#   7,
#   374,
#   48,
#   430,
#   6,
#   40,
#   48,
#   88,
#   181,
#   51,
#   861,
#   15,
#   418,
#   374,
#   51,
#   861,
#   3,
#   73,
#   1505,
#   4,
#   1,
#   767,
#   48,
#   79,
#   5,
#   195,
#   689,
#   3,
#   1506,
#   7,
#   5,
#   76,
#   574,
#   3071,
#   5804,
#   418,
#   374,
#   243,
#   2172,
#   2535,
#   1891,
#   2,
#   2538,
#   463,
#   31,
#   12,
#   9,
#   3072,
#   553,
#   4,
#   970,
#   442,
#   26,
#   553,
#   6,
#   1154,
#   439,
#   292,
#   553,
#   6,
#   17,
#   1350,
#   15,
#   418,
#   374,
#   553,
#   6,
#   98,
#   3,
#   523,
#   255,
#   388,
#   971,
#   12,
#   15,
#   1224,
#   690,
#   106,
#   809,
#   1351,
#   17,
#   862,
#   11,
#   33,
#   63,
#   12,
#   7,
#   592,
#   810,
#   4,
#   1,
#   76,
#   418,
#   374,
#   9,
#   5805,
#   15,
#   51,
#   972,
#   3073,
#   13,
#   9,
#   309,
#   1,
#   915,
#   157,
#   1352,
#   42,
#   504,
#   418,
#   374,
#   811,
#   148,
#   5,
#   101,
#   15,
#   33,
#   2,
#   482,
#   5,
#   1225,
#   15,
#   1,
#   5806,
#   1678,
#   442,
#   71,
#   17,
#   1350,
#   15,
#   418,
#   374,
#   23,
#   1895,
#   26,
#   98,
#   3,
#   523,
#   26,
#   388,
#   50,
#   12,
#   9,
#   32,
#   3953,
#   12,
#   9,
#   32,
#   5,
#   217,
#   15,
#   5,
#   375,
#   13,
#   9,
#   1,
#   186,
#   4,
#   5807,
#   182,
#   7,
#   914,
#   15,
#   196,
#   3074,
#   37,
#   418,
#   374,
#   50,
#   4,
#   1678,
#   3075,
#   2,
#   77,
#   310,
#   1,
#   431,
#   376,
#   3954,
#   3955,
#   6,
#   7,
#   3956,
#   361,
#   268,
#   442,
#   87,
#   28,
#   5808,
#   4,
#   418,
#   374,
#   916,
#   50,
#   38,
#   87,
#   32,
#   28,
#   320,
#   3076,
#   3,
#   3077,
#   61,
#   3,
#   719,
#   1,
#   1679,
#   20,
#   87,
#   122,
#   5,
#   5809,
#   768,
#   20,
#   87,
#   863,
#   12,
#   25,
#   20,
#   161,
#   688,
#   18,
#   971,
#   50,
#   38,
#   17,
#   93,
#   420,
#   5810,
#   17,
#   1,
#   690,
#   8,
#   3957,
#   575,
#   4,
#   1,
#   36,
#   5,
#   1896,
#   5811,
#   5812,
#   575,
#   3,
#   149,
#   51,
#   1507,
#   3,
#   256,
#   51,
#   1507,
#   3,
#   91,
#   71,
#   18,
#   93,
#   103,
#   51,
#   1507,
#   6,
#   87,
#   28,
#   3078,
#   2,
#   5813,
#   51,
#   1507,
#   6,
#   87,
#   5814,
#   1,
#   1053,
#   374,
#   243,
#   2,
#   311,
#   1,
#   2173,
#   3,
#   418,
#   374,
#   15,
#   127,
#   1350,
#   720,
#   3958,
#   4,
#   24,
#   20,
#   5815,
#   102,
#   20,
#   192,
#   43,
#   24,
#   504,
#   321,
#   27,
#   61,
#   2535,
#   1891,
#   2,
#   2538,
#   17,
#   123,
#   143,
#   1054,
#   53,
#   4,
#   1,
#   5816,
#   2540,
#   442,
#   37,
#   5817,
#   293,
#   262,
#   3959,
#   156,
#   108,
#   3,
#   5818,
#   1,
#   5819,
#   11,
#   44,
#   283,
#   29,
#   24,
#   343,
#   339,
#   2,
#   239,
#   1,
#   409,
#   377,
#   4,
#   1,
#   284,
#   3,
#   73,
#   116,
#   12,
#   11,
#   330,
#   53,
#   3,
#   257,
#   5,
#   387,
#   6,
#   87,
#   1055,
#   141,
#   483,
#   1226,
#   1,
#   1227,
#   4,
#   418,
#   374,
#   2,
#   56,
#   54,
#   11,
#   119,
#   12,
#   106,
#   3960,
#   2,
#   5820,
#   1227,
#   242,
#   1351,
#   18,
#   3961,
#   6,
#   1897,
#   1351,
#   82,
#   11,
#   82,
#   108,
#   3,
#   863,
#   45,
#   3961,
#   19,
#   3,
#   42,
#   442,
#   20,
#   82,
#   464,
#   11,
#   125,
#   82,
#   108,
#   3,
#   1056,
#   27,
#   1228,
#   38,
#   17,
#   93,
#   1898,
#   4,
#   3076,
#   7,
#   1897,
#   575,
#   113,
#   1057,
#   769,
#   3,
#   864,
#   29,
#   1,
#   121,
#   4,
#   1,
#   1508,
#   2541,
#   3962,
#   17,
#   125,
#   94,
#   42,
#   442,
#   82,
#   108,
#   3,
#   812,
#   60,
#   219,
#   311,
#   2174,
#   813,
#   2,
#   1,
#   3963,
#   4,
#   1509,
#   71,
#   17,
#   691,
#   64,
#   1899,
#   62,
#   721,
#   2,
#   2542,
#   11,
#   82,
#   108,
#   3,
#   1502,
#   42,
#   442,
#   3,
#   812,
#   3962,
#   33,
#   4,
#   42,
#   1510,
#   139,
#   5821,
#   1509,
#   1,
#   112,
#   862,
#   522,
#   7,
#   146,
#   575,
#   1353,
#   3964,
#   139,
#   721,
#   3,
#   42,
#   442,
#   99,
#   1680,
#   4,
#   61,
#   973,
#   5822,
#   3079,
#   5823,
#   1509,
#   2,
#   3080,
#   5824,
#   37,
#   269,
#   1351,
#   245,
#   31,
#   3965,
#   3966,
#   5825,
#   2,
#   2543,
#   180,
#   19,
#   555,
#   3,
#   200,
#   42,
#   5826,
#   9,
#   42,
#   1354,
#   7,
#   5827,
#   556,
#   11,
#   140,
#   13,
#   331,
#   5828,
#   387,
#   3,
#   2544,
#   42,
#   442,
#   37,
#   33,
#   99,
#   1,
#   76,
#   3,
#   974,
#   2,
#   523,
#   179,
#   2,
#   125,
#   3,
#   1229,
#   1,
#   74,
#   42,
#   1509,
#   108,
#   3,
#   3081,
#   99,
#   770,
#   5829,
#   1,
#   284,
#   79,
#   183,
#   72,
#   5,
#   340,
#   975,
#   13,
#   387,
#   23,
#   1155,
#   22,
#   244,
#   1900,
#   117,
#   54,
#   11,
#   30,
#   12,
#   11,
#   123,
#   1058,
#   100,
#   1681,
#   400,
#   3967,
#   2,
#   362,
#   248,
#   1,
#   100,
#   1681,
#   112,
#   7,
#   1679,
#   1682,
#   1,
#   100,
#   1681,
#   6,
#   17,
#   5830,
#   3,
#   200,
#   42,
#   442,
#   181,
#   5,
#   454,
#   55,
#   42,
#   442,
#   17,
#   2540,
#   20,
#   17,
#   2175,
#   7,
#   5,
#   332,
#   2176,
#   4,
#   359,
#   3,
#   484,
#   442,
#   3,
#   2545,
#   6,
#   91,
#   71,
#   108,
#   3968,
#   443,
#   73,
#   12,
#   3969,
#   15,
#   127,
#   5831,
#   285,
#   20,
#   719,
#   5,
#   124,
#   3082,
#   5,
#   223,
#   124,
#   330,
#   4,
#   442,
#   37,
#   33,
#   99,
#   1,
#   76,
#   127,
#   513,
#   55,
#   20,
#   92,
#   89,
#   1,
#   2176,
#   20,
#   181,
#   1,
#   1508,
#   1901,
#   4,
#   1,
#   513,
#   1,
#   1683,
#   2546,
#   1,
#   2177,
#   2546,
#   2,
#   1,
#   1355,
#   209,
#   59,
#   9,
#   1,
#   1511,
#   4,
#   42,
#   976,
#   127,
#   513,
#   127,
#   720,
#   514,
#   2547,
#   3,
#   1,
#   770,
#   1355,
#   2,
#   125,
#   514,
#   3970,
#   19,
#   1,
#   2548,
#   4,
#   432,
#   13,
#   97,
#   11,
#   311,
#   42,
#   442,
#   1512,
#   11,
#   1155,
#   5,
#   865,
#   2178,
#   7,
#   3083,
#   2549,
#   128,
#   3971,
#   60,
#   1,
#   220,
#   4,
#   169,
#   513,
#   1,
#   442,
#   122,
#   5,
#   5832,
#   263,
#   7,
#   64,
#   2177,
#   59,
#   17,
#   5833,
#   60,
#   64,
#   1902,
#   389,
#   1,
#   3084,
#   4,
#   1,
#   5834,
#   73,
#   5,
#   1684,
#   390,
#   3,
#   1,
#   170,
#   513,
#   60,
#   1,
#   220,
#   4,
#   1,
#   ...],
#  [2554,
#   7,
#   557,
#   76,
#   204,
#   9,
#   5,
#   47,
#   1687,
#   576,
#   50,
#   128,
#   37,
#   433,
#   43,
#   374,
#   43,
#   3978,
#   12,
#   3979,
#   3,
#   73,
#   1513,
#   31,
#   1230,
#   271,
#   3980,
#   1904,
#   5,
#   3981,
#   387,
#   2554,
#   31,
#   112,
#   103,
#   557,
#   441,
#   275,
#   57,
#   105,
#   5,
#   444,
#   4,
#   242,
#   43,
#   323,
#   9,
#   5,
#   444,
#   4,
#   593,
#   2183,
#   1,
#   164,
#   2184,
#   7,
#   557,
#   293,
#   366,
#   12,
#   533,
#   3,
#   58,
#   15,
#   196,
#   6,
#   7,
#   816,
#   4,
#   1688,
#   51,
#   867,
#   276,
#   9,
#   32,
#   39,
#   102,
#   130,
#   1,
#   445,
#   140,
#   515,
#   25,
#   434,
#   39,
#   102,
#   130,
#   1,
#   1060,
#   140,
#   324,
#   1688,
#   43,
#   1358,
#   15,
#   196,
#   7,
#   5850,
#   57,
#   105,
#   484,
#   159,
#   4,
#   1,
#   723,
#   1359,
#   1358,
#   979,
#   1,
#   165,
#   6,
#   1,
#   3982,
#   79,
#   5,
#   418,
#   1514,
#   814,
#   5851,
#   105,
#   1,
#   435,
#   335,
#   38,
#   9,
#   5,
#   577,
#   7,
#   557,
#   76,
#   204,
#   15,
#   242,
#   15,
#   817,
#   1689,
#   40,
#   57,
#   242,
#   9,
#   2555,
#   7,
#   2556,
#   4,
#   285,
#   38,
#   9,
#   236,
#   242,
#   15,
#   3978,
#   15,
#   1061,
#   15,
#   2185,
#   2,
#   125,
#   38,
#   9,
#   5,
#   577,
#   15,
#   349,
#   38,
#   9,
#   5,
#   577,
#   15,
#   349,
#   224,
#   91,
#   21,
#   515,
#   2,
#   91,
#   360,
#   61,
#   112,
#   4,
#   72,
#   1360,
#   142,
#   6,
#   1515,
#   1062,
#   2,
#   5,
#   724,
#   868,
#   9,
#   1,
#   237,
#   97,
#   3,
#   1063,
#   112,
#   4,
#   3983,
#   813,
#   818,
#   38,
#   9,
#   5,
#   157,
#   21,
#   6,
#   6,
#   724,
#   868,
#   769,
#   2184,
#   4,
#   1514,
#   7,
#   534,
#   3,
#   138,
#   75,
#   36,
#   514,
#   95,
#   57,
#   242,
#   75,
#   432,
#   236,
#   75,
#   869,
#   1690,
#   432,
#   1905,
#   78,
#   24,
#   132,
#   4,
#   593,
#   23,
#   11,
#   325,
#   15,
#   142,
#   21,
#   5,
#   724,
#   5852,
#   65,
#   2557,
#   100,
#   485,
#   59,
#   378,
#   18,
#   104,
#   3,
#   30,
#   21,
#   204,
#   1,
#   106,
#   39,
#   9,
#   593,
#   4,
#   692,
#   4,
#   133,
#   819,
#   15,
#   190,
#   6,
#   33,
#   190,
#   171,
#   18,
#   1064,
#   1,
#   2186,
#   433,
#   2,
#   374,
#   971,
#   3,
#   820,
#   980,
#   3,
#   1906,
#   5853,
#   3,
#   2558,
#   2559,
#   3,
#   594,
#   1516,
#   2,
#   1,
#   252,
#   132,
#   4,
#   593,
#   9,
#   39,
#   59,
#   11,
#   88,
#   312,
#   981,
#   593,
#   1,
#   106,
#   1065,
#   7,
#   127,
#   3087,
#   335,
#   6,
#   33,
#   1231,
#   17,
#   982,
#   173,
#   1,
#   1158,
#   6,
#   9,
#   32,
#   44,
#   3984,
#   22,
#   5,
#   47,
#   693,
#   1159,
#   15,
#   196,
#   40,
#   6,
#   9,
#   455,
#   5,
#   1517,
#   21,
#   725,
#   3088,
#   79,
#   5,
#   101,
#   3,
#   725,
#   313,
#   57,
#   983,
#   349,
#   105,
#   5,
#   558,
#   21,
#   5854,
#   18,
#   85,
#   16,
#   239,
#   3,
#   2184,
#   294,
#   6,
#   22,
#   173,
#   42,
#   5855,
#   2,
#   11,
#   30,
#   32,
#   58,
#   12,
#   236,
#   105,
#   361,
#   70,
#   153,
#   182,
#   88,
#   32,
#   2187,
#   2,
#   12,
#   1232,
#   984,
#   7,
#   1,
#   137,
#   97,
#   6,
#   12,
#   985,
#   984,
#   142,
#   3,
#   58,
#   5,
#   1517,
#   7,
#   2560,
#   7,
#   165,
#   55,
#   8,
#   482,
#   1907,
#   3089,
#   6,
#   981,
#   1159,
#   6,
#   324,
#   131,
#   5856,
#   99,
#   1515,
#   1066,
#   6,
#   5,
#   1517,
#   21,
#   361,
#   36,
#   79,
#   5,
#   101,
#   3,
#   361,
#   313,
#   57,
#   983,
#   349,
#   105,
#   5,
#   558,
#   11,
#   2561,
#   5,
#   1691,
#   2562,
#   243,
#   524,
#   19,
#   1233,
#   7,
#   3985,
#   3986,
#   11,
#   158,
#   12,
#   5857,
#   7,
#   534,
#   3,
#   95,
#   1233,
#   3987,
#   2,
#   39,
#   107,
#   9,
#   6,
#   12,
#   9,
#   125,
#   5,
#   47,
#   559,
#   981,
#   2188,
#   50,
#   31,
#   1233,
#   5858,
#   60,
#   862,
#   515,
#   1234,
#   7,
#   2560,
#   12,
#   1904,
#   9,
#   483,
#   5,
#   345,
#   4,
#   446,
#   29,
#   138,
#   7,
#   165,
#   22,
#   32,
#   44,
#   5,
#   444,
#   4,
#   2183,
#   12,
#   218,
#   122,
#   5859,
#   5,
#   2563,
#   4,
#   3988,
#   190,
#   65,
#   181,
#   53,
#   7,
#   359,
#   595,
#   6,
#   1,
#   112,
#   2189,
#   97,
#   3,
#   140,
#   5860,
#   983,
#   349,
#   9,
#   21,
#   3985,
#   3986,
#   15,
#   1233,
#   7,
#   165,
#   1233,
#   17,
#   32,
#   3090,
#   25,
#   20,
#   17,
#   1,
#   123,
#   295,
#   221,
#   3,
#   486,
#   1691,
#   2562,
#   3,
#   33,
#   1067,
#   4,
#   918,
#   694,
#   557,
#   204,
#   20,
#   125,
#   18,
#   164,
#   1228,
#   15,
#   196,
#   13,
#   243,
#   7,
#   5861,
#   9,
#   535,
#   57,
#   3088,
#   42,
#   919,
#   105,
#   33,
#   5862,
#   986,
#   7,
#   1518,
#   920,
#   15,
#   39,
#   522,
#   7,
#   1361,
#   29,
#   5,
#   2564,
#   4,
#   1,
#   5863,
#   2565,
#   32,
#   44,
#   15,
#   349,
#   15,
#   1233,
#   25,
#   11,
#   2565,
#   15,
#   349,
#   15,
#   36,
#   2,
#   6,
#   14,
#   130,
#   57,
#   533,
#   204,
#   17,
#   177,
#   2566,
#   2,
#   11,
#   606,
#   17,
#   2190,
#   44,
#   31,
#   1160,
#   108,
#   3,
#   3091,
#   43,
#   2191,
#   108,
#   3,
#   921,
#   43,
#   5864,
#   108,
#   3,
#   350,
#   11,
#   108,
#   3,
#   560,
#   38,
#   9,
#   5,
#   68,
#   2192,
#   577,
#   55,
#   11,
#   17,
#   296,
#   27,
#   557,
#   441,
#   204,
#   224,
#   2190,
#   2,
#   515,
#   77,
#   24,
#   10,
#   58,
#   9,
#   5,
#   345,
#   6,
#   609,
#   5865,
#   446,
#   24,
#   13,
#   609,
#   9,
#   6,
#   36,
#   71,
#   560,
#   17,
#   5866,
#   1231,
#   401,
#   91,
#   71,
#   92,
#   7,
#   515,
#   17,
#   5867,
#   1231,
#   7,
#   816,
#   4,
#   1688,
#   1908,
#   24,
#   68,
#   366,
#   5,
#   610,
#   224,
#   867,
#   2,
#   5868,
#   204,
#   9,
#   32,
#   2556,
#   43,
#   5869,
#   25,
#   692,
#   3092,
#   77,
#   20,
#   183,
#   5,
#   5870,
#   309,
#   47,
#   5871,
#   2,
#   20,
#   3989,
#   3,
#   95,
#   5,
#   5872,
#   13,
#   9,
#   5873,
#   33,
#   99,
#   1,
#   76,
#   32,
#   130,
#   5874,
#   17,
#   57,
#   207,
#   105,
#   5875,
#   34,
#   276,
#   4,
#   3093,
#   11,
#   2565,
#   5,
#   47,
#   533,
#   2567,
#   7,
#   534,
#   3,
#   122,
#   349,
#   37,
#   515,
#   59,
#   49,
#   85,
#   2193,
#   19,
#   3092,
#   15,
#   1362,
#   7,
#   534,
#   3,
#   95,
#   349,
#   15,
#   36,
#   6,
#   171,
#   1692,
#   1909,
#   4,
#   177,
#   1161,
#   2,
#   3,
#   95,
#   349,
#   15,
#   2194,
#   3094,
#   106,
#   4,
#   33,
#   8,
#   49,
#   611,
#   2568,
#   173,
#   6,
#   2,
#   8,
#   14,
#   483,
#   5876,
#   7,
#   1,
#   305,
#   12,
#   9,
#   5,
#   47,
#   533,
#   2567,
#   818,
#   12,
#   14,
#   295,
#   561,
#   168,
#   47,
#   533,
#   3990,
#   3,
#   95,
#   5,
#   276,
#   6,
#   65,
#   1692,
#   75,
#   821,
#   15,
#   177,
#   1909,
#   6,
#   65,
#   166,
#   6,
#   91,
#   71,
#   560,
#   17,
#   1910,
#   207,
#   3,
#   91,
#   71,
#   18,
#   515,
#   870,
#   5,
#   47,
#   207,
#   5877,
#   2,
#   456,
#   1162,
#   822,
#   9,
#   54,
#   3,
#   3095,
#   6,
#   112,
#   1911,
#   1693,
#   4,
#   5,
#   276,
#   59,
#   9,
#   983,
#   349,
#   5,
#   276,
#   88,
#   181,
#   1163,
#   43,
#   3991,
#   1912,
#   2,
#   12,
#   65,
#   32,
#   28,
#   16,
#   1911,
#   31,
#   983,
#   349,
#   54,
#   3,
#   3095,
#   12,
#   224,
#   2190,
#   1358,
#   324,
#   1688,
#   2,
#   515,
#   13,
#   9,
#   32,
#   5,
#   1363,
#   1162,
#   2,
#   11,
#   171,
#   369,
#   6,
#   7,
#   93,
#   3087,
#   2193,
#   9,
#   5,
#   5878,
#   101,
#   55,
#   11,
#   95,
#   6,
#   5879,
#   125,
#   447,
#   2,
#   13,
#   14,
#   612,
#   70,
#   153,
#   173,
#   38,
#   35,
#   3094,
#   7,
#   124,
#   823,
#   43,
#   7,
#   3992,
#   43,
#   7,
#   613,
#   12,
#   14,
#   5,
#   47,
#   533,
#   2567,
#   31,
#   90,
#   57,
#   105,
#   5880,
#   1235,
#   4,
#   2194,
#   1164,
#   429,
#   8,
#   82,
#   67,
#   2194,
#   1164,
#   429,
#   17,
#   5,
#   2569,
#   2195,
#   2196,
#   20,
#   17,
#   5,
#   101,
#   44,
#   31,
#   3092,
#   17,
#   922,
#   11,
#   208,
#   6,
#   123,
#   91,
#   21,
#   971,
#   3,
#   5,
#   1519,
#   1913,
#   18,
#   5,
#   101,
#   3,
#   1068,
#   2554,
#   ...],
#  [8,
#   2578,
#   1,
#   539,
#   100,
#   70,
#   3,
#   827,
#   54,
#   36,
#   1523,
#   64,
#   872,
#   55,
#   11,
#   67,
#   27,
#   1,
#   872,
#   11,
#   18,
#   2,
#   1,
#   5911,
#   11,
#   98,
#   3,
#   440,
#   7,
#   1,
#   526,
#   12,
#   9,
#   2200,
#   3,
#   58,
#   54,
#   174,
#   4,
#   51,
#   5912,
#   38,
#   9,
#   224,
#   1,
#   872,
#   6,
#   11,
#   18,
#   2,
#   772,
#   6,
#   154,
#   4009,
#   83,
#   77,
#   3,
#   155,
#   3,
#   10,
#   142,
#   27,
#   240,
#   429,
#   54,
#   32,
#   3,
#   1156,
#   69,
#   5913,
#   208,
#   7,
#   1238,
#   598,
#   10,
#   63,
#   1,
#   186,
#   101,
#   1,
#   4010,
#   466,
#   447,
#   5,
#   1524,
#   1920,
#   2,
#   1921,
#   12,
#   47,
#   918,
#   15,
#   5,
#   135,
#   4,
#   242,
#   10,
#   63,
#   1,
#   186,
#   238,
#   924,
#   297,
#   25,
#   8,
#   3104,
#   22,
#   3105,
#   40,
#   10,
#   92,
#   3106,
#   773,
#   1,
#   466,
#   79,
#   232,
#   484,
#   3107,
#   173,
#   2,
#   48,
#   79,
#   232,
#   5,
#   2579,
#   19,
#   1,
#   2201,
#   5,
#   5914,
#   48,
#   79,
#   85,
#   339,
#   19,
#   1,
#   2201,
#   15,
#   359,
#   4011,
#   9,
#   68,
#   272,
#   8,
#   436,
#   18,
#   5,
#   186,
#   7,
#   1922,
#   6,
#   36,
#   67,
#   9,
#   51,
#   1238,
#   598,
#   8,
#   139,
#   37,
#   5,
#   2202,
#   328,
#   2,
#   100,
#   411,
#   173,
#   1,
#   5915,
#   3,
#   1923,
#   15,
#   3108,
#   8,
#   160,
#   1,
#   4012,
#   305,
#   2,
#   5916,
#   8,
#   109,
#   7,
#   36,
#   238,
#   67,
#   22,
#   51,
#   1238,
#   598,
#   25,
#   6,
#   123,
#   765,
#   50,
#   15,
#   1,
#   1924,
#   70,
#   4013,
#   3,
#   6,
#   8,
#   314,
#   133,
#   2,
#   374,
#   1525,
#   69,
#   1238,
#   598,
#   186,
#   9,
#   225,
#   5,
#   1073,
#   4,
#   289,
#   286,
#   232,
#   7,
#   69,
#   133,
#   136,
#   6,
#   5917,
#   208,
#   403,
#   540,
#   79,
#   1,
#   3109,
#   15,
#   10,
#   1925,
#   36,
#   98,
#   3,
#   200,
#   53,
#   101,
#   33,
#   695,
#   4,
#   36,
#   69,
#   328,
#   69,
#   467,
#   69,
#   400,
#   1697,
#   20,
#   33,
#   18,
#   3110,
#   19,
#   59,
#   1526,
#   10,
#   171,
#   122,
#   2,
#   193,
#   46,
#   163,
#   10,
#   92,
#   136,
#   13,
#   4014,
#   25,
#   2203,
#   10,
#   92,
#   354,
#   38,
#   17,
#   103,
#   429,
#   10,
#   18,
#   3,
#   718,
#   31,
#   90,
#   2,
#   10,
#   108,
#   3,
#   95,
#   91,
#   1527,
#   562,
#   93,
#   39,
#   540,
#   79,
#   1,
#   686,
#   3109,
#   15,
#   69,
#   133,
#   2,
#   10,
#   108,
#   3,
#   527,
#   2204,
#   91,
#   1527,
#   101,
#   1,
#   4015,
#   17,
#   2205,
#   2,
#   110,
#   66,
#   3,
#   2580,
#   69,
#   615,
#   2,
#   22,
#   5,
#   176,
#   4,
#   1,
#   5918,
#   2,
#   22,
#   47,
#   3111,
#   25,
#   47,
#   207,
#   990,
#   3,
#   1926,
#   55,
#   925,
#   9,
#   2206,
#   16,
#   55,
#   69,
#   133,
#   9,
#   66,
#   164,
#   10,
#   18,
#   145,
#   179,
#   5,
#   164,
#   541,
#   2,
#   10,
#   18,
#   694,
#   2581,
#   2,
#   289,
#   9,
#   330,
#   26,
#   74,
#   3,
#   1926,
#   55,
#   8,
#   1698,
#   34,
#   106,
#   457,
#   8,
#   765,
#   68,
#   68,
#   326,
#   3,
#   3095,
#   12,
#   728,
#   7,
#   1922,
#   21,
#   6,
#   99,
#   143,
#   268,
#   36,
#   2582,
#   12,
#   99,
#   4016,
#   36,
#   1168,
#   528,
#   5919,
#   55,
#   8,
#   563,
#   5,
#   5920,
#   75,
#   774,
#   14,
#   2206,
#   130,
#   40,
#   8,
#   119,
#   81,
#   4017,
#   65,
#   28,
#   529,
#   25,
#   529,
#   9,
#   154,
#   529,
#   55,
#   110,
#   694,
#   597,
#   5,
#   991,
#   10,
#   108,
#   3,
#   138,
#   926,
#   105,
#   277,
#   2,
#   181,
#   562,
#   203,
#   991,
#   246,
#   40,
#   8,
#   119,
#   81,
#   5,
#   351,
#   992,
#   1074,
#   36,
#   65,
#   468,
#   12,
#   2,
#   56,
#   164,
#   265,
#   25,
#   40,
#   8,
#   138,
#   926,
#   105,
#   277,
#   8,
#   23,
#   486,
#   13,
#   226,
#   62,
#   3,
#   553,
#   56,
#   118,
#   8,
#   564,
#   21,
#   34,
#   124,
#   457,
#   3,
#   92,
#   3,
#   127,
#   488,
#   489,
#   4,
#   1922,
#   2,
#   8,
#   23,
#   265,
#   58,
#   5,
#   418,
#   991,
#   120,
#   93,
#   74,
#   3,
#   1926,
#   5921,
#   3112,
#   2,
#   56,
#   68,
#   207,
#   208,
#   1,
#   2207,
#   9,
#   403,
#   1927,
#   8,
#   1925,
#   58,
#   36,
#   393,
#   448,
#   8,
#   49,
#   13,
#   164,
#   185,
#   25,
#   93,
#   4018,
#   49,
#   1,
#   978,
#   3,
#   1239,
#   355,
#   8,
#   487,
#   13,
#   164,
#   1369,
#   25,
#   1,
#   724,
#   9,
#   16,
#   290,
#   1,
#   4017,
#   156,
#   92,
#   90,
#   43,
#   8,
#   178,
#   181,
#   131,
#   1928,
#   34,
#   541,
#   9,
#   16,
#   1528,
#   4019,
#   40,
#   10,
#   18,
#   872,
#   22,
#   69,
#   1370,
#   3,
#   95,
#   61,
#   490,
#   448,
#   12,
#   238,
#   28,
#   326,
#   3,
#   181,
#   1928,
#   448,
#   1,
#   724,
#   238,
#   28,
#   290,
#   25,
#   40,
#   93,
#   39,
#   2555,
#   7,
#   69,
#   185,
#   40,
#   93,
#   39,
#   1168,
#   69,
#   1369,
#   15,
#   353,
#   38,
#   9,
#   94,
#   38,
#   6,
#   9,
#   69,
#   5922,
#   10,
#   108,
#   3,
#   73,
#   69,
#   872,
#   2,
#   95,
#   61,
#   490,
#   2,
#   93,
#   39,
#   4020,
#   64,
#   927,
#   616,
#   25,
#   40,
#   10,
#   156,
#   95,
#   61,
#   490,
#   22,
#   69,
#   2207,
#   2,
#   93,
#   39,
#   1927,
#   28,
#   1169,
#   15,
#   69,
#   5923,
#   39,
#   150,
#   3112,
#   2,
#   13,
#   39,
#   9,
#   68,
#   207,
#   31,
#   90,
#   208,
#   6,
#   1,
#   123,
#   96,
#   6,
#   444,
#   17,
#   1,
#   872,
#   422,
#   358,
#   8,
#   381,
#   51,
#   3113,
#   2,
#   12,
#   14,
#   5,
#   135,
#   4,
#   467,
#   20,
#   35,
#   66,
#   62,
#   5,
#   394,
#   12,
#   14,
#   5,
#   47,
#   439,
#   394,
#   2,
#   12,
#   14,
#   5,
#   135,
#   4,
#   138,
#   10,
#   88,
#   58,
#   6,
#   20,
#   35,
#   5924,
#   2,
#   13,
#   14,
#   2583,
#   2,
#   20,
#   35,
#   66,
#   62,
#   2,
#   20,
#   561,
#   183,
#   12,
#   3,
#   1,
#   991,
#   4,
#   285,
#   20,
#   564,
#   3,
#   1371,
#   101,
#   83,
#   66,
#   3,
#   1371,
#   16,
#   448,
#   11,
#   183,
#   12,
#   35,
#   29,
#   1,
#   269,
#   100,
#   874,
#   380,
#   39,
#   301,
#   29,
#   1,
#   103,
#   2,
#   321,
#   529,
#   214,
#   92,
#   5925,
#   9,
#   154,
#   27,
#   1,
#   927,
#   422,
#   133,
#   9,
#   27,
#   1,
#   617,
#   448,
#   10,
#   171,
#   1237,
#   1,
#   927,
#   422,
#   25,
#   36,
#   67,
#   6,
#   10,
#   18,
#   872,
#   2,
#   2203,
#   10,
#   73,
#   3,
#   1699,
#   39,
#   4,
#   91,
#   872,
#   22,
#   5,
#   1529,
#   217,
#   102,
#   1367,
#   87,
#   28,
#   33,
#   116,
#   25,
#   5926,
#   5,
#   808,
#   9,
#   5,
#   5927,
#   1929,
#   2,
#   69,
#   133,
#   9,
#   32,
#   1,
#   123,
#   97,
#   3,
#   68,
#   1523,
#   33,
#   4,
#   69,
#   872,
#   9,
#   3,
#   1157,
#   1237,
#   127,
#   579,
#   4,
#   69,
#   617,
#   56,
#   1,
#   237,
#   5928,
#   69,
#   617,
#   9,
#   391,
#   26,
#   22,
#   183,
#   4,
#   1930,
#   75,
#   1930,
#   87,
#   28,
#   101,
#   19,
#   294,
#   10,
#   87,
#   2208,
#   40,
#   22,
#   101,
#   19,
#   1371,
#   50,
#   75,
#   36,
#   775,
#   5,
#   135,
#   3,
#   1371,
#   2,
#   40,
#   10,
#   5929,
#   371,
#   6,
#   89,
#   94,
#   3,
#   278,
#   40,
#   127,
#   579,
#   729,
#   94,
#   3,
#   278,
#   43,
#   94,
#   3,
#   1371,
#   10,
#   87,
#   15,
#   353,
#   1237,
#   1,
#   5930,
#   240,
#   5931,
#   208,
#   7,
#   1238,
#   598,
#   208,
#   403,
#   540,
#   79,
#   1,
#   3109,
#   15,
#   10,
#   208,
#   6,
#   55,
#   925,
#   9,
#   2206,
#   10,
#   171,
#   1926,
#   141,
#   208,
#   1,
#   2207,
#   9,
#   403,
#   1927,
#   2,
#   208,
#   6,
#   123,
#   1,
#   927,
#   422,
#   444,
#   208,
#   46,
#   10,
#   30,
#   6,
#   2,
#   10,
#   87,
#   5932,
#   69,
#   5933,
#   5934],
#  [55,
#   8,
#   14,
#   2584,
#   15,
#   13,
#   155,
#   8,
#   198,
#   3,
#   1372,
#   15,
#   5,
#   351,
#   4,
#   3114,
#   6,
#   8,
#   23,
#   428,
#   21,
#   10,
#   131,
#   449,
#   8,
#   247,
#   143,
#   6,
#   8,
#   1071,
#   2585,
#   1,
#   106,
#   60,
#   4021,
#   4022,
#   71,
#   80,
#   55,
#   336,
#   69,
#   423,
#   7,
#   133,
#   30,
#   32,
#   1170,
#   3,
#   192,
#   1,
#   252,
#   60,
#   5935,
#   71,
#   2586,
#   72,
#   6,
#   1367,
#   9,
#   5,
#   423,
#   6,
#   1931,
#   2587,
#   2,
#   1,
#   431,
#   9,
#   39,
#   60,
#   5936,
#   5937,
#   71,
#   80,
#   8,
#   776,
#   98,
#   3,
#   565,
#   3,
#   5938,
#   3,
#   146,
#   2209,
#   6,
#   65,
#   18,
#   46,
#   31,
#   5,
#   5939,
#   290,
#   449,
#   8,
#   156,
#   63,
#   59,
#   39,
#   4,
#   45,
#   3114,
#   3,
#   565,
#   2,
#   428,
#   21,
#   10,
#   1,
#   2210,
#   1240,
#   4,
#   5940,
#   2211,
#   313,
#   4,
#   5941,
#   4023,
#   423,
#   179,
#   21,
#   618,
#   730,
#   2,
#   1,
#   185,
#   4,
#   5942,
#   79,
#   85,
#   4024,
#   3,
#   51,
#   2588,
#   52,
#   179,
#   21,
#   13,
#   11,
#   125,
#   18,
#   5,
#   1354,
#   7,
#   3115,
#   1932,
#   25,
#   1,
#   5943,
#   4,
#   13,
#   1171,
#   79,
#   85,
#   51,
#   993,
#   4,
#   1240,
#   2589,
#   4,
#   4025,
#   2589,
#   4,
#   148,
#   5944,
#   341,
#   6,
#   11,
#   17,
#   3072,
#   7,
#   42,
#   635,
#   2590,
#   13,
#   1171,
#   4,
#   618,
#   423,
#   79,
#   3074,
#   72,
#   37,
#   253,
#   27,
#   298,
#   659,
#   12,
#   3116,
#   6,
#   13,
#   1171,
#   14,
#   113,
#   47,
#   2189,
#   7,
#   5945,
#   72,
#   31,
#   456,
#   2,
#   298,
#   3117,
#   491,
#   4,
#   336,
#   298,
#   5946,
#   11,
#   17,
#   57,
#   2,
#   57,
#   1700,
#   7,
#   5947,
#   294,
#   3,
#   1,
#   273,
#   4,
#   5948,
#   54,
#   139,
#   6,
#   1171,
#   4,
#   423,
#   9,
#   161,
#   16,
#   693,
#   130,
#   731,
#   36,
#   71,
#   18,
#   32,
#   134,
#   96,
#   3,
#   565,
#   731,
#   54,
#   139,
#   6,
#   130,
#   36,
#   71,
#   17,
#   445,
#   47,
#   104,
#   161,
#   2212,
#   21,
#   1,
#   185,
#   4,
#   423,
#   1,
#   132,
#   4,
#   2213,
#   185,
#   4,
#   423,
#   59,
#   11,
#   5949,
#   1,
#   1171,
#   4,
#   423,
#   9,
#   47,
#   928,
#   7,
#   3118,
#   15,
#   72,
#   5,
#   349,
#   3,
#   67,
#   27,
#   75,
#   2591,
#   244,
#   193,
#   46,
#   149,
#   10,
#   51,
#   196,
#   34,
#   661,
#   2592,
#   55,
#   84,
#   14,
#   5,
#   720,
#   29,
#   575,
#   7,
#   777,
#   14,
#   4026,
#   242,
#   60,
#   339,
#   15,
#   5,
#   558,
#   5950,
#   52,
#   2592,
#   55,
#   84,
#   5951,
#   1,
#   1933,
#   4027,
#   65,
#   2214,
#   21,
#   206,
#   27,
#   111,
#   3119,
#   54,
#   104,
#   48,
#   828,
#   3,
#   732,
#   54,
#   134,
#   190,
#   48,
#   79,
#   24,
#   194,
#   48,
#   108,
#   1,
#   558,
#   15,
#   20,
#   65,
#   994,
#   139,
#   3,
#   5,
#   131,
#   4028,
#   24,
#   65,
#   28,
#   5,
#   686,
#   558,
#   52,
#   173,
#   2593,
#   4027,
#   65,
#   92,
#   288,
#   2,
#   67,
#   96,
#   136,
#   84,
#   65,
#   114,
#   3,
#   206,
#   1,
#   558,
#   6,
#   10,
#   17,
#   1934,
#   52,
#   9,
#   686,
#   25,
#   7,
#   5,
#   191,
#   70,
#   74,
#   55,
#   69,
#   333,
#   87,
#   28,
#   265,
#   53,
#   4,
#   1,
#   372,
#   55,
#   10,
#   87,
#   18,
#   5,
#   81,
#   210,
#   57,
#   242,
#   6,
#   103,
#   558,
#   87,
#   28,
#   2588,
#   25,
#   24,
#   10,
#   17,
#   1934,
#   52,
#   9,
#   164,
#   52,
#   1,
#   1530,
#   4,
#   2593,
#   3120,
#   71,
#   180,
#   121,
#   1,
#   170,
#   151,
#   1168,
#   6,
#   103,
#   558,
#   1,
#   558,
#   20,
#   119,
#   32,
#   108,
#   1,
#   558,
#   6,
#   1227,
#   392,
#   227,
#   104,
#   242,
#   52,
#   2592,
#   482,
#   16,
#   928,
#   7,
#   3121,
#   515,
#   6,
#   687,
#   84,
#   829,
#   19,
#   3,
#   3121,
#   4029,
#   2,
#   1935,
#   16,
#   104,
#   27,
#   1,
#   5952,
#   4,
#   36,
#   2215,
#   86,
#   90,
#   15,
#   86,
#   1053,
#   454,
#   59,
#   9,
#   6,
#   4,
#   5,
#   5953,
#   118,
#   35,
#   2593,
#   3120,
#   16,
#   4030,
#   2593,
#   598,
#   14,
#   6,
#   84,
#   14,
#   167,
#   3,
#   311,
#   7,
#   64,
#   2216,
#   51,
#   492,
#   4,
#   51,
#   5954,
#   244,
#   51,
#   492,
#   4,
#   422,
#   55,
#   20,
#   17,
#   265,
#   57,
#   928,
#   5955,
#   2,
#   15,
#   61,
#   1373,
#   6,
#   103,
#   558,
#   14,
#   31,
#   40,
#   20,
#   17,
#   322,
#   995,
#   3,
#   13,
#   2588,
#   7,
#   59,
#   12,
#   14,
#   31,
#   40,
#   2592,
#   265,
#   381,
#   3122,
#   11,
#   3123,
#   95,
#   68,
#   996,
#   2213,
#   635,
#   635,
#   17,
#   4031,
#   60,
#   42,
#   3124,
#   60,
#   42,
#   274,
#   35,
#   367,
#   1373,
#   60,
#   4032,
#   24,
#   65,
#   103,
#   36,
#   67,
#   27,
#   42,
#   423,
#   125,
#   11,
#   17,
#   1373,
#   60,
#   212,
#   29,
#   24,
#   432,
#   17,
#   1373,
#   35,
#   125,
#   4032,
#   24,
#   9,
#   1936,
#   5956,
#   423,
#   52,
#   50,
#   4,
#   13,
#   11,
#   113,
#   130,
#   168,
#   11,
#   18,
#   265,
#   2217,
#   41,
#   1168,
#   5,
#   558,
#   3125,
#   468,
#   5957,
#   27,
#   515,
#   31,
#   40,
#   11,
#   161,
#   98,
#   3,
#   4033,
#   599,
#   6,
#   11,
#   183,
#   1,
#   101,
#   5958,
#   635,
#   17,
#   4034,
#   20,
#   17,
#   1701,
#   3,
#   696,
#   3126,
#   20,
#   17,
#   1531,
#   4035,
#   52,
#   50,
#   4,
#   13,
#   36,
#   18,
#   52,
#   57,
#   2,
#   57,
#   275,
#   6,
#   20,
#   17,
#   32,
#   1373,
#   249,
#   32,
#   187,
#   153,
#   8,
#   14,
#   29,
#   5,
#   3127,
#   5959,
#   2,
#   8,
#   662,
#   5,
#   410,
#   559,
#   375,
#   71,
#   1241,
#   160,
#   580,
#   46,
#   27,
#   86,
#   1240,
#   99,
#   423,
#   84,
#   80,
#   3,
#   46,
#   8,
#   493,
#   39,
#   1153,
#   3,
#   990,
#   59,
#   5960,
#   3,
#   1242,
#   78,
#   84,
#   80,
#   15,
#   411,
#   8,
#   14,
#   2218,
#   59,
#   1702,
#   3,
#   830,
#   15,
#   13,
#   39,
#   591,
#   2,
#   52,
#   8,
#   108,
#   3,
#   565,
#   5,
#   4036,
#   3128,
#   8,
#   283,
#   29,
#   13,
#   375,
#   7,
#   3129,
#   4036,
#   3128,
#   216,
#   1,
#   5961,
#   84,
#   80,
#   83,
#   997,
#   608,
#   29,
#   1,
#   220,
#   4,
#   13,
#   201,
#   2,
#   115,
#   85,
#   16,
#   290,
#   7,
#   1373,
#   213,
#   7,
#   34,
#   5962,
#   423,
#   50,
#   22,
#   1701,
#   3,
#   824,
#   9,
#   4034,
#   2,
#   12,
#   14,
#   265,
#   1,
#   929,
#   5963,
#   1532,
#   5964,
#   5965,
#   71,
#   4037,
#   53,
#   6,
#   1240,
#   9,
#   1701,
#   3,
#   1,
#   1172,
#   4,
#   1172,
#   52,
#   11,
#   67,
#   142,
#   6,
#   11,
#   23,
#   1243,
#   45,
#   696,
#   11,
#   18,
#   3115,
#   724,
#   1937,
#   5966,
#   4,
#   1,
#   244,
#   5967,
#   130,
#   21,
#   724,
#   59,
#   9,
#   27,
#   689,
#   5968,
#   11,
#   67,
#   11,
#   23,
#   2594,
#   3130,
#   102,
#   22,
#   5969,
#   689,
#   9,
#   113,
#   1903,
#   47,
#   2219,
#   150,
#   201,
#   34,
#   661,
#   3131,
#   5970,
#   29,
#   1,
#   575,
#   4,
#   1938,
#   1521,
#   51,
#   1533,
#   5,
#   1374,
#   19,
#   1,
#   185,
#   4,
#   689,
#   48,
#   2,
#   8,
#   35,
#   179,
#   19,
#   1,
#   4038,
#   2,
#   44,
#   173,
#   5971,
#   42,
#   1703,
#   26,
#   11,
#   156,
#   63,
#   169,
#   432,
#   1703,
#   26,
#   11,
#   564,
#   3,
#   122,
#   689,
#   1525,
#   16,
#   11,
#   2595,
#   42,
#   778,
#   6,
#   24,
#   20,
#   87,
#   44,
#   52,
#   412,
#   87,
#   28,
#   5,
#   1244,
#   636,
#   5,
#   3132,
#   4,
#   1,
#   100,
#   1703,
#   59,
#   11,
#   156,
#   63,
#   24,
#   169,
#   14,
#   998,
#   52,
#   11,
#   2220,
#   1,
#   1374,
#   7,
#   245,
#   5,
#   97,
#   3131,
#   468,
#   111,
#   106,
#   2596,
#   8,
#   468,
#   34,
#   106,
#   2596,
#   3131,
#   468,
#   111,
#   252,
#   2596,
#   8,
#   468,
#   34,
#   252,
#   2596,
#   7,
#   13,
#   97,
#   597,
#   1,
#   220,
#   4,
#   42,
#   1703,
#   52,
#   10,
#   87,
#   28,
#   1375,
#   6,
#   5,
#   1530,
#   4,
#   42,
#   778,
#   119,
#   32,
#   67,
#   6,
#   24,
#   999,
#   44,
#   3133,
#   3,
#   14,
#   5,
#   379,
#   1244,
#   636,
#   20,
#   494,
#   208,
#   6,
#   875,
#   37,
#   1,
#   831,
#   4,
#   1704,
#   41,
#   100,
#   1509,
#   11,
#   35,
#   ...],
#  [11,
#   17,
#   447,
#   53,
#   4,
#   47,
#   332,
#   342,
#   2,
#   11,
#   17,
#   3145,
#   7,
#   5,
#   47,
#   592,
#   1943,
#   2,
#   1,
#   165,
#   9,
#   6,
#   11,
#   17,
#   32,
#   47,
#   131,
#   29,
#   827,
#   270,
#   29,
#   669,
#   4,
#   91,
#   6006,
#   2,
#   56,
#   50,
#   42,
#   876,
#   833,
#   3146,
#   3,
#   259,
#   1,
#   76,
#   29,
#   6,
#   6007,
#   35,
#   3147,
#   19,
#   13,
#   47,
#   1944,
#   1711,
#   4,
#   4054,
#   101,
#   7,
#   1,
#   508,
#   25,
#   12,
#   472,
#   1173,
#   50,
#   130,
#   29,
#   6,
#   1711,
#   4,
#   270,
#   6,
#   11,
#   312,
#   288,
#   35,
#   32,
#   452,
#   112,
#   4,
#   1,
#   1712,
#   56,
#   66,
#   19,
#   16,
#   122,
#   1,
#   2226,
#   4,
#   42,
#   76,
#   13,
#   9,
#   699,
#   1537,
#   6008,
#   4041,
#   6,
#   4055,
#   254,
#   1538,
#   2,
#   12,
#   1539,
#   3148,
#   3149,
#   7,
#   1,
#   121,
#   4,
#   42,
#   495,
#   25,
#   35,
#   32,
#   452,
#   33,
#   1,
#   1537,
#   53,
#   38,
#   7,
#   165,
#   24,
#   11,
#   58,
#   9,
#   236,
#   105,
#   5,
#   260,
#   6009,
#   4,
#   216,
#   53,
#   38,
#   16,
#   10,
#   18,
#   1378,
#   1537,
#   2,
#   6010,
#   2,
#   6011,
#   2,
#   6012,
#   6013,
#   1945,
#   136,
#   69,
#   458,
#   101,
#   52,
#   2,
#   110,
#   379,
#   6014,
#   4,
#   12,
#   50,
#   10,
#   82,
#   139,
#   21,
#   1,
#   2227,
#   1946,
#   3149,
#   15,
#   2204,
#   12,
#   62,
#   38,
#   17,
#   496,
#   4,
#   930,
#   1379,
#   1380,
#   1945,
#   136,
#   10,
#   101,
#   52,
#   2,
#   110,
#   2610,
#   663,
#   3,
#   1707,
#   22,
#   32,
#   6,
#   45,
#   96,
#   17,
#   3150,
#   6015,
#   4056,
#   1540,
#   75,
#   2611,
#   7,
#   64,
#   270,
#   2,
#   6016,
#   1540,
#   3151,
#   7,
#   64,
#   639,
#   4,
#   1,
#   76,
#   2,
#   4,
#   285,
#   11,
#   257,
#   1247,
#   7,
#   1,
#   4057,
#   4,
#   42,
#   515,
#   3,
#   718,
#   62,
#   19,
#   600,
#   7,
#   1,
#   1378,
#   3152,
#   1001,
#   2,
#   11,
#   447,
#   1247,
#   7,
#   2185,
#   3,
#   718,
#   62,
#   19,
#   1,
#   6017,
#   1001,
#   25,
#   10,
#   178,
#   279,
#   146,
#   4,
#   91,
#   60,
#   562,
#   29,
#   700,
#   32,
#   255,
#   50,
#   10,
#   82,
#   139,
#   6018,
#   21,
#   1,
#   2227,
#   6019,
#   24,
#   13,
#   221,
#   9,
#   6,
#   42,
#   424,
#   4,
#   270,
#   9,
#   6020,
#   60,
#   42,
#   1713,
#   2,
#   6,
#   373,
#   779,
#   1,
#   640,
#   279,
#   4058,
#   6,
#   42,
#   495,
#   2,
#   42,
#   1714,
#   2,
#   42,
#   3153,
#   17,
#   44,
#   2204,
#   62,
#   1,
#   2228,
#   270,
#   56,
#   53,
#   38,
#   491,
#   42,
#   876,
#   17,
#   6021,
#   44,
#   5,
#   81,
#   210,
#   4,
#   1,
#   4059,
#   383,
#   1,
#   1075,
#   2612,
#   128,
#   641,
#   718,
#   62,
#   19,
#   128,
#   810,
#   4,
#   270,
#   16,
#   7,
#   1,
#   663,
#   2,
#   1381,
#   76,
#   4,
#   1,
#   4060,
#   1,
#   207,
#   600,
#   17,
#   1947,
#   2,
#   6022,
#   4061,
#   7,
#   1,
#   76,
#   4,
#   1,
#   611,
#   4062,
#   4063,
#   22,
#   1076,
#   76,
#   9,
#   6023,
#   3154,
#   60,
#   1948,
#   4064,
#   2,
#   15,
#   1,
#   6024,
#   4065,
#   22,
#   270,
#   9,
#   3155,
#   53,
#   4,
#   404,
#   6025,
#   1537,
#   56,
#   1,
#   1711,
#   4,
#   64,
#   4066,
#   6,
#   20,
#   23,
#   718,
#   62,
#   19,
#   2,
#   11,
#   18,
#   5,
#   414,
#   15,
#   13,
#   7,
#   248,
#   22,
#   158,
#   1,
#   2229,
#   59,
#   9,
#   1,
#   1382,
#   414,
#   15,
#   1,
#   2613,
#   76,
#   52,
#   6026,
#   127,
#   1075,
#   4067,
#   6,
#   22,
#   2229,
#   9,
#   1,
#   722,
#   2228,
#   270,
#   53,
#   38,
#   50,
#   118,
#   65,
#   10,
#   277,
#   518,
#   3,
#   352,
#   6,
#   120,
#   94,
#   1064,
#   24,
#   11,
#   23,
#   279,
#   491,
#   24,
#   11,
#   33,
#   30,
#   9,
#   11,
#   1360,
#   270,
#   31,
#   22,
#   2230,
#   3,
#   6027,
#   30,
#   5,
#   6028,
#   19,
#   13,
#   352,
#   6,
#   10,
#   17,
#   5,
#   6029,
#   1949,
#   69,
#   223,
#   76,
#   9,
#   27,
#   6030,
#   286,
#   109,
#   5,
#   187,
#   6031,
#   6,
#   79,
#   780,
#   268,
#   4068,
#   3149,
#   7,
#   12,
#   2,
#   10,
#   18,
#   6032,
#   4069,
#   6,
#   6033,
#   2,
#   6034,
#   4068,
#   1248,
#   2,
#   69,
#   4069,
#   130,
#   18,
#   6035,
#   16,
#   10,
#   23,
#   122,
#   174,
#   6036,
#   4,
#   404,
#   289,
#   9,
#   27,
#   1383,
#   15,
#   10,
#   16,
#   39,
#   151,
#   10,
#   518,
#   7,
#   69,
#   4070,
#   21,
#   5,
#   6037,
#   10,
#   117,
#   29,
#   69,
#   177,
#   2231,
#   2,
#   10,
#   67,
#   24,
#   9,
#   12,
#   41,
#   3,
#   18,
#   1,
#   6038,
#   6039,
#   3156,
#   4,
#   5,
#   177,
#   24,
#   9,
#   12,
#   41,
#   55,
#   10,
#   122,
#   5,
#   6040,
#   81,
#   6041,
#   4,
#   404,
#   54,
#   23,
#   10,
#   32,
#   63,
#   6,
#   120,
#   5,
#   1715,
#   361,
#   4071,
#   188,
#   43,
#   6,
#   69,
#   4072,
#   14,
#   19,
#   13,
#   47,
#   4073,
#   473,
#   471,
#   153,
#   16,
#   50,
#   35,
#   606,
#   144,
#   154,
#   931,
#   6,
#   76,
#   4,
#   1383,
#   16,
#   11,
#   82,
#   2614,
#   12,
#   50,
#   11,
#   17,
#   6042,
#   6043,
#   89,
#   42,
#   2229,
#   25,
#   1,
#   209,
#   9,
#   30,
#   11,
#   18,
#   3,
#   28,
#   1234,
#   38,
#   16,
#   31,
#   5,
#   4074,
#   83,
#   1249,
#   7,
#   1,
#   97,
#   6,
#   323,
#   175,
#   1716,
#   42,
#   2229,
#   2,
#   54,
#   56,
#   66,
#   3,
#   147,
#   1,
#   424,
#   4,
#   148,
#   6044,
#   11,
#   265,
#   63,
#   6,
#   11,
#   23,
#   6045,
#   42,
#   323,
#   3,
#   42,
#   1713,
#   50,
#   38,
#   17,
#   727,
#   4,
#   496,
#   4,
#   36,
#   1250,
#   116,
#   21,
#   1717,
#   1077,
#   2,
#   1717,
#   978,
#   16,
#   1,
#   97,
#   13,
#   365,
#   9,
#   10,
#   122,
#   5,
#   6046,
#   2,
#   10,
#   1078,
#   1,
#   1541,
#   2,
#   10,
#   145,
#   51,
#   2615,
#   2616,
#   1079,
#   89,
#   1,
#   2232,
#   3157,
#   43,
#   21,
#   1,
#   6047,
#   3158,
#   10,
#   122,
#   5,
#   581,
#   2,
#   10,
#   1078,
#   1,
#   1541,
#   2,
#   78,
#   10,
#   3159,
#   51,
#   2615,
#   3160,
#   1079,
#   89,
#   1,
#   4075,
#   878,
#   2,
#   31,
#   578,
#   31,
#   612,
#   70,
#   153,
#   38,
#   35,
#   5,
#   135,
#   4,
#   1174,
#   71,
#   228,
#   45,
#   1384,
#   776,
#   138,
#   118,
#   22,
#   50,
#   45,
#   1384,
#   596,
#   1,
#   405,
#   4,
#   1385,
#   734,
#   2,
#   22,
#   32,
#   463,
#   1,
#   137,
#   6048,
#   31,
#   42,
#   871,
#   1946,
#   279,
#   4076,
#   25,
#   1,
#   165,
#   9,
#   6,
#   12,
#   365,
#   1,
#   250,
#   1718,
#   53,
#   54,
#   3,
#   140,
#   1,
#   600,
#   44,
#   6049,
#   54,
#   30,
#   11,
#   259,
#   6,
#   90,
#   222,
#   1,
#   174,
#   1719,
#   69,
#   250,
#   9,
#   32,
#   1077,
#   43,
#   452,
#   146,
#   4,
#   13,
#   69,
#   250,
#   9,
#   3161,
#   7,
#   5,
#   6050,
#   4,
#   2617,
#   2,
#   6051,
#   354,
#   69,
#   6052,
#   33,
#   12,
#   277,
#   1542,
#   17,
#   4077,
#   600,
#   6,
#   139,
#   7,
#   620,
#   128,
#   229,
#   6053,
#   2,
#   13,
#   9,
#   33,
#   12,
#   79,
#   3,
#   138,
#   21,
#   2,
#   299,
#   57,
#   52,
#   1720,
#   1,
#   250,
#   9,
#   68,
#   131,
#   29,
#   364,
#   7,
#   45,
#   600,
#   2,
#   4078,
#   781,
#   2,
#   6054,
#   701,
#   16,
#   6,
#   12,
#   621,
#   13,
#   2232,
#   1943,
#   2,
#   2618,
#   179,
#   5,
#   186,
#   4,
#   13,
#   69,
#   6055,
#   4079,
#   222,
#   1,
#   622,
#   273,
#   69,
#   250,
#   218,
#   63,
#   2,
#   12,
#   218,
#   303,
#   102,
#   12,
#   472,
#   1,
#   229,
#   37,
#   567,
#   469,
#   310,
#   7,
#   12,
#   44,
#   1718,
#   53,
#   24,
#   3,
#   30,
#   21,
#   12,
#   2,
#   13,
#   9,
#   5,
#   47,
#   2189,
#   132,
#   4,
#   1002,
#   22,
#   879,
#   5,
#   1175,
#   2233,
#   4080,
#   1003,
#   2,
#   12,
#   44,
#   621,
#   7,
#   289,
#   2,
#   1718,
#   53,
#   24,
#   22,
#   66,
#   3,
#   30,
#   21,
#   12,
#   2,
#   6,
#   8,
#   67,
#   6056,
#   62,
#   623,
#   582,
#   3,
#   6057,
#   116,
#   21,
#   128,
#   695,
#   4,
#   4081,
#   6058,
#   8,
#   312,
#   13,
#   1,
#   3162,
#   387,
#   4,
#   1251,
#   2,
#   8,
#   82,
#   98,
#   3,
#   73,
#   227,
#   2619,
#   77,
#   25,
#   3162,
#   2234,
#   15,
#   ...],
#  [1,
#   425,
#   11,
#   163,
#   27,
#   169,
#   103,
#   444,
#   47,
#   104,
#   1,
#   425,
#   11,
#   163,
#   599,
#   27,
#   42,
#   189,
#   233,
#   444,
#   2,
#   112,
#   4,
#   33,
#   8,
#   67,
#   1,
#   97,
#   6,
#   11,
#   1732,
#   7,
#   169,
#   432,
#   425,
#   9,
#   4,
#   625,
#   2637,
#   8,
#   14,
#   473,
#   70,
#   234,
#   55,
#   8,
#   106,
#   338,
#   425,
#   27,
#   1,
#   445,
#   52,
#   8,
#   156,
#   412,
#   91,
#   425,
#   37,
#   1,
#   445,
#   422,
#   8,
#   338,
#   61,
#   37,
#   34,
#   2638,
#   292,
#   1084,
#   2,
#   1393,
#   132,
#   4,
#   3167,
#   34,
#   2638,
#   292,
#   1084,
#   8,
#   369,
#   556,
#   6,
#   36,
#   71,
#   35,
#   445,
#   493,
#   94,
#   1899,
#   26,
#   426,
#   4098,
#   4125,
#   26,
#   6,
#   20,
#   156,
#   18,
#   2,
#   8,
#   125,
#   14,
#   1085,
#   6172,
#   21,
#   6,
#   6,
#   12,
#   14,
#   34,
#   454,
#   26,
#   13,
#   2176,
#   738,
#   4,
#   240,
#   2,
#   473,
#   1394,
#   190,
#   26,
#   12,
#   14,
#   42,
#   454,
#   3193,
#   3,
#   200,
#   13,
#   9,
#   24,
#   1393,
#   280,
#   4,
#   72,
#   2,
#   78,
#   48,
#   80,
#   24,
#   10,
#   30,
#   15,
#   1,
#   700,
#   4,
#   45,
#   10,
#   30,
#   15,
#   46,
#   52,
#   8,
#   14,
#   307,
#   6173,
#   8,
#   14,
#   47,
#   4126,
#   3,
#   28,
#   2255,
#   7,
#   1,
#   76,
#   26,
#   8,
#   67,
#   11,
#   33,
#   18,
#   6,
#   341,
#   2,
#   125,
#   12,
#   14,
#   132,
#   4,
#   272,
#   6,
#   319,
#   493,
#   200,
#   6,
#   14,
#   449,
#   3,
#   46,
#   2,
#   12,
#   510,
#   41,
#   12,
#   14,
#   5,
#   47,
#   207,
#   107,
#   3,
#   73,
#   3,
#   1732,
#   6174,
#   8,
#   125,
#   460,
#   47,
#   687,
#   6175,
#   6,
#   1393,
#   125,
#   80,
#   2,
#   83,
#   6176,
#   1,
#   445,
#   65,
#   225,
#   28,
#   21,
#   72,
#   13,
#   2639,
#   2,
#   2640,
#   46,
#   8,
#   510,
#   41,
#   8,
#   49,
#   85,
#   44,
#   519,
#   5,
#   2177,
#   2546,
#   6,
#   8,
#   49,
#   3,
#   30,
#   2,
#   8,
#   14,
#   1006,
#   3,
#   30,
#   25,
#   93,
#   444,
#   24,
#   8,
#   65,
#   30,
#   8,
#   65,
#   1905,
#   16,
#   8,
#   510,
#   2640,
#   5,
#   81,
#   210,
#   2639,
#   2,
#   1733,
#   41,
#   246,
#   476,
#   4127,
#   94,
#   77,
#   2,
#   8,
#   510,
#   3194,
#   2,
#   15,
#   1,
#   106,
#   74,
#   8,
#   1395,
#   3,
#   633,
#   13,
#   415,
#   4,
#   36,
#   2,
#   3,
#   152,
#   1181,
#   2248,
#   597,
#   5,
#   223,
#   415,
#   4,
#   36,
#   8,
#   2591,
#   7,
#   34,
#   615,
#   5,
#   132,
#   4,
#   187,
#   522,
#   4,
#   910,
#   6,
#   35,
#   154,
#   66,
#   188,
#   6,
#   65,
#   225,
#   28,
#   21,
#   72,
#   20,
#   35,
#   225,
#   66,
#   3,
#   363,
#   46,
#   3,
#   200,
#   61,
#   2,
#   149,
#   61,
#   96,
#   59,
#   8,
#   14,
#   1006,
#   3,
#   30,
#   25,
#   8,
#   156,
#   63,
#   54,
#   12,
#   14,
#   66,
#   3,
#   138,
#   2,
#   8,
#   156,
#   63,
#   24,
#   65,
#   490,
#   55,
#   8,
#   1261,
#   53,
#   4,
#   96,
#   3,
#   149,
#   819,
#   40,
#   1,
#   157,
#   14,
#   154,
#   66,
#   188,
#   7,
#   1,
#   70,
#   825,
#   1,
#   103,
#   425,
#   8,
#   338,
#   27,
#   1,
#   445,
#   694,
#   62,
#   35,
#   93,
#   57,
#   865,
#   15,
#   196,
#   8,
#   381,
#   520,
#   2,
#   1008,
#   4128,
#   4,
#   3195,
#   2,
#   1009,
#   8,
#   338,
#   27,
#   96,
#   6,
#   35,
#   66,
#   421,
#   7,
#   1,
#   233,
#   4,
#   1,
#   445,
#   8,
#   338,
#   27,
#   704,
#   8,
#   338,
#   27,
#   503,
#   26,
#   20,
#   225,
#   1232,
#   3,
#   28,
#   132,
#   4,
#   3196,
#   2,
#   7,
#   1175,
#   8,
#   109,
#   13,
#   230,
#   4,
#   185,
#   6,
#   1,
#   445,
#   7,
#   1,
#   76,
#   1262,
#   233,
#   6,
#   35,
#   6177,
#   21,
#   1009,
#   2,
#   3195,
#   6178,
#   6179,
#   168,
#   5,
#   401,
#   8,
#   935,
#   24,
#   8,
#   67,
#   134,
#   4,
#   72,
#   30,
#   9,
#   13,
#   2256,
#   1086,
#   102,
#   8,
#   160,
#   3,
#   152,
#   290,
#   127,
#   74,
#   8,
#   338,
#   27,
#   61,
#   8,
#   160,
#   3,
#   152,
#   3139,
#   15,
#   34,
#   189,
#   3197,
#   6180,
#   50,
#   8,
#   343,
#   162,
#   57,
#   3193,
#   3,
#   95,
#   96,
#   195,
#   2,
#   8,
#   130,
#   510,
#   5,
#   279,
#   4,
#   3198,
#   50,
#   4,
#   6,
#   2,
#   16,
#   4129,
#   8,
#   160,
#   3,
#   1182,
#   436,
#   8,
#   811,
#   1962,
#   3,
#   64,
#   425,
#   337,
#   31,
#   2257,
#   31,
#   8,
#   49,
#   173,
#   2,
#   8,
#   811,
#   2641,
#   96,
#   3,
#   68,
#   147,
#   52,
#   8,
#   161,
#   419,
#   26,
#   19,
#   1,
#   427,
#   12,
#   283,
#   41,
#   8,
#   14,
#   161,
#   337,
#   1010,
#   8,
#   419,
#   4,
#   34,
#   74,
#   2,
#   34,
#   242,
#   8,
#   419,
#   55,
#   742,
#   35,
#   19,
#   2642,
#   1,
#   1227,
#   4,
#   5,
#   4091,
#   4,
#   2239,
#   23,
#   643,
#   5,
#   4130,
#   133,
#   101,
#   8,
#   258,
#   71,
#   23,
#   4131,
#   21,
#   6,
#   8,
#   419,
#   55,
#   8,
#   14,
#   6181,
#   55,
#   12,
#   14,
#   533,
#   3,
#   3199,
#   2,
#   8,
#   419,
#   7,
#   1175,
#   55,
#   1,
#   1181,
#   1548,
#   447,
#   62,
#   320,
#   6,
#   8,
#   419,
#   3,
#   6182,
#   34,
#   189,
#   1009,
#   32,
#   403,
#   1927,
#   1,
#   1549,
#   28,
#   437,
#   8,
#   14,
#   544,
#   53,
#   4,
#   6,
#   217,
#   32,
#   53,
#   4,
#   5,
#   4132,
#   217,
#   4,
#   325,
#   2,
#   6183,
#   3,
#   200,
#   2,
#   4,
#   3963,
#   12,
#   482,
#   5,
#   6184,
#   15,
#   46,
#   482,
#   230,
#   4,
#   5,
#   1734,
#   8,
#   14,
#   6185,
#   94,
#   26,
#   8,
#   14,
#   1934,
#   34,
#   101,
#   3,
#   92,
#   19,
#   21,
#   34,
#   151,
#   2,
#   32,
#   2251,
#   28,
#   6186,
#   60,
#   13,
#   290,
#   449,
#   2,
#   8,
#   67,
#   1,
#   97,
#   6,
#   11,
#   92,
#   136,
#   6,
#   294,
#   23,
#   106,
#   4,
#   33,
#   6187,
#   5,
#   415,
#   4,
#   36,
#   910,
#   53,
#   38,
#   7,
#   1,
#   76,
#   2,
#   12,
#   23,
#   125,
#   371,
#   89,
#   5,
#   6188,
#   59,
#   9,
#   5,
#   47,
#   1396,
#   107,
#   16,
#   31,
#   8,
#   119,
#   13,
#   2,
#   31,
#   8,
#   67,
#   134,
#   4,
#   72,
#   30,
#   13,
#   11,
#   132,
#   4,
#   812,
#   42,
#   1182,
#   11,
#   132,
#   4,
#   812,
#   42,
#   101,
#   3,
#   92,
#   19,
#   21,
#   42,
#   151,
#   8,
#   67,
#   6,
#   1550,
#   23,
#   113,
#   73,
#   7,
#   1,
#   97,
#   4,
#   1,
#   47,
#   107,
#   6,
#   11,
#   98,
#   112,
#   12,
#   23,
#   73,
#   7,
#   1,
#   97,
#   4,
#   42,
#   2643,
#   3,
#   68,
#   28,
#   1963,
#   2,
#   2255,
#   7,
#   203,
#   2258,
#   133,
#   2,
#   7,
#   786,
#   3,
#   6189,
#   5,
#   191,
#   70,
#   153,
#   96,
#   3200,
#   15,
#   46,
#   50,
#   8,
#   338,
#   13,
#   3201,
#   596,
#   1263,
#   6190,
#   3202,
#   8,
#   63,
#   134,
#   7,
#   1,
#   281,
#   309,
#   63,
#   463,
#   71,
#   48,
#   9,
#   25,
#   3,
#   149,
#   1,
#   6191,
#   2259,
#   15,
#   146,
#   71,
#   18,
#   32,
#   338,
#   206,
#   596,
#   1263,
#   3202,
#   1011,
#   1,
#   4133,
#   1087,
#   2260,
#   5,
#   191,
#   70,
#   153,
#   15,
#   111,
#   138,
#   6192,
#   509,
#   4134,
#   55,
#   8,
#   338,
#   206,
#   596,
#   12,
#   14,
#   143,
#   70,
#   173,
#   6,
#   25,
#   461,
#   4134,
#   26,
#   40,
#   13,
#   9,
#   124,
#   3,
#   10,
#   31,
#   90,
#   26,
#   67,
#   4,
#   6,
#   31,
#   809,
#   1264,
#   15,
#   1,
#   445,
#   67,
#   4,
#   33,
#   1,
#   96,
#   10,
#   73,
#   29,
#   69,
#   1397,
#   2,
#   352,
#   91,
#   2261,
#   2,
#   1264,
#   4135,
#   3,
#   1,
#   769,
#   4,
#   403,
#   329,
#   19,
#   5,
#   191,
#   344,
#   5,
#   151,
#   1263,
#   3202,
#   1551,
#   111,
#   186,
#   1552,
#   24,
#   6,
#   14,
#   2,
#   24,
#   48,
#   49,
#   232,
#   21,
#   111,
#   6193,
#   1397,
#   48,
#   125,
#   787,
#   27,
#   7,
#   626,
#   6194,
#   59,
#   9,
#   5,
#   644,
#   3203,
#   6,
#   88,
#   200,
#   403,
#   202,
#   43,
#   923,
#   5,
#   400,
#   52,
#   55,
#   8,
#   338,
#   206,
#   596,
#   12,
#   14,
#   1012,
#   15,
#   5,
#   226,
#   4,
#   690,
#   106,
#   2,
#   6195,
#   8,
#   ...],
#  [90,
#   56,
#   132,
#   4,
#   51,
#   2186,
#   2660,
#   62,
#   38,
#   8,
#   160,
#   21,
#   6,
#   1743,
#   27,
#   1094,
#   70,
#   153,
#   2,
#   8,
#   160,
#   7,
#   1,
#   1095,
#   4,
#   557,
#   293,
#   25,
#   110,
#   498,
#   77,
#   37,
#   127,
#   1096,
#   4,
#   1,
#   76,
#   16,
#   40,
#   10,
#   67,
#   4,
#   5,
#   748,
#   4,
#   69,
#   441,
#   8,
#   67,
#   511,
#   1016,
#   6,
#   15,
#   127,
#   441,
#   19,
#   512,
#   10,
#   88,
#   1403,
#   81,
#   4181,
#   3,
#   114,
#   45,
#   17,
#   420,
#   102,
#   131,
#   1189,
#   688,
#   92,
#   19,
#   269,
#   4,
#   6,
#   91,
#   17,
#   1,
#   420,
#   37,
#   102,
#   2661,
#   310,
#   16,
#   11,
#   18,
#   51,
#   6248,
#   157,
#   26,
#   131,
#   1189,
#   82,
#   98,
#   3,
#   92,
#   3,
#   44,
#   91,
#   420,
#   102,
#   129,
#   493,
#   1,
#   6249,
#   160,
#   7,
#   6250,
#   3,
#   346,
#   2,
#   1190,
#   13,
#   157,
#   21,
#   51,
#   642,
#   59,
#   14,
#   5,
#   47,
#   391,
#   642,
#   7,
#   124,
#   1981,
#   8,
#   461,
#   3145,
#   5,
#   362,
#   89,
#   5,
#   1744,
#   4,
#   5,
#   6251,
#   7,
#   124,
#   1981,
#   1,
#   190,
#   2571,
#   198,
#   3,
#   292,
#   20,
#   156,
#   63,
#   146,
#   465,
#   26,
#   999,
#   154,
#   282,
#   5,
#   362,
#   173,
#   2,
#   20,
#   156,
#   63,
#   24,
#   1,
#   284,
#   14,
#   8,
#   1404,
#   439,
#   1563,
#   284,
#   3,
#   12,
#   26,
#   22,
#   27,
#   143,
#   549,
#   254,
#   1,
#   749,
#   26,
#   574,
#   12,
#   19,
#   2,
#   287,
#   12,
#   38,
#   168,
#   13,
#   11,
#   1191,
#   5,
#   351,
#   4,
#   272,
#   96,
#   59,
#   511,
#   58,
#   25,
#   8,
#   2662,
#   13,
#   33,
#   99,
#   1166,
#   2,
#   78,
#   136,
#   5,
#   592,
#   176,
#   4,
#   1,
#   76,
#   2,
#   1191,
#   6,
#   190,
#   87,
#   278,
#   3,
#   30,
#   24,
#   20,
#   98,
#   3,
#   278,
#   3,
#   6252,
#   9,
#   1,
#   106,
#   642,
#   6,
#   11,
#   119,
#   26,
#   628,
#   1394,
#   675,
#   19,
#   69,
#   101,
#   2279,
#   111,
#   720,
#   5,
#   473,
#   1394,
#   479,
#   2,
#   48,
#   14,
#   2279,
#   86,
#   54,
#   3,
#   4182,
#   13,
#   675,
#   77,
#   7,
#   1,
#   508,
#   4,
#   888,
#   1166,
#   26,
#   13,
#   9,
#   7,
#   5,
#   6253,
#   975,
#   102,
#   1,
#   190,
#   2663,
#   64,
#   189,
#   594,
#   2,
#   78,
#   1564,
#   12,
#   121,
#   3,
#   169,
#   103,
#   2,
#   7,
#   1,
#   305,
#   645,
#   6254,
#   422,
#   6255,
#   20,
#   119,
#   33,
#   4,
#   13,
#   7,
#   197,
#   471,
#   168,
#   452,
#   1,
#   362,
#   15,
#   1,
#   106,
#   74,
#   7,
#   203,
#   607,
#   4183,
#   975,
#   45,
#   1097,
#   77,
#   49,
#   6256,
#   5,
#   505,
#   581,
#   2,
#   35,
#   316,
#   3,
#   122,
#   1,
#   1565,
#   4,
#   5,
#   6257,
#   1566,
#   20,
#   2582,
#   12,
#   37,
#   6258,
#   43,
#   39,
#   4,
#   45,
#   1982,
#   1745,
#   266,
#   168,
#   691,
#   1,
#   362,
#   7,
#   64,
#   975,
#   16,
#   29,
#   1,
#   220,
#   4,
#   12,
#   11,
#   4184,
#   6,
#   385,
#   4,
#   190,
#   23,
#   278,
#   3,
#   140,
#   1405,
#   2,
#   1,
#   284,
#   19,
#   64,
#   189,
#   6259,
#   4,
#   71,
#   43,
#   102,
#   20,
#   6260,
#   6,
#   273,
#   8,
#   482,
#   5,
#   81,
#   57,
#   1919,
#   2,
#   564,
#   3,
#   58,
#   24,
#   540,
#   88,
#   190,
#   30,
#   21,
#   5,
#   362,
#   11,
#   160,
#   254,
#   21,
#   51,
#   642,
#   7,
#   6261,
#   1166,
#   102,
#   8,
#   419,
#   5,
#   415,
#   4,
#   190,
#   26,
#   20,
#   1746,
#   465,
#   21,
#   5,
#   47,
#   1089,
#   6262,
#   3229,
#   8,
#   419,
#   61,
#   5,
#   362,
#   21,
#   5,
#   4185,
#   3230,
#   59,
#   10,
#   52,
#   73,
#   721,
#   21,
#   2664,
#   2,
#   280,
#   61,
#   3,
#   596,
#   89,
#   12,
#   16,
#   55,
#   20,
#   1746,
#   89,
#   12,
#   1,
#   362,
#   2665,
#   53,
#   6263,
#   16,
#   20,
#   80,
#   90,
#   12,
#   218,
#   259,
#   249,
#   4,
#   24,
#   11,
#   17,
#   393,
#   16,
#   8,
#   80,
#   384,
#   397,
#   440,
#   12,
#   77,
#   15,
#   100,
#   334,
#   95,
#   562,
#   1274,
#   3,
#   1,
#   362,
#   16,
#   1,
#   190,
#   80,
#   54,
#   30,
#   11,
#   30,
#   6,
#   2,
#   8,
#   80,
#   8,
#   82,
#   63,
#   113,
#   2,
#   8,
#   287,
#   100,
#   334,
#   380,
#   26,
#   2,
#   13,
#   9,
#   52,
#   4186,
#   7,
#   1,
#   469,
#   323,
#   15,
#   739,
#   839,
#   2624,
#   26,
#   6,
#   6264,
#   49,
#   538,
#   2,
#   35,
#   2666,
#   478,
#   3,
#   1,
#   1958,
#   1983,
#   3229,
#   7,
#   59,
#   8,
#   49,
#   1567,
#   1,
#   4185,
#   6265,
#   7,
#   103,
#   395,
#   20,
#   35,
#   33,
#   875,
#   41,
#   4187,
#   6266,
#   16,
#   20,
#   88,
#   30,
#   6,
#   19,
#   64,
#   189,
#   168,
#   6,
#   8,
#   160,
#   3,
#   642,
#   21,
#   1224,
#   103,
#   96,
#   6,
#   20,
#   175,
#   278,
#   3,
#   30,
#   19,
#   64,
#   6267,
#   109,
#   51,
#   272,
#   1379,
#   312,
#   358,
#   37,
#   6268,
#   37,
#   1,
#   658,
#   2667,
#   2280,
#   4188,
#   71,
#   80,
#   8,
#   98,
#   3,
#   58,
#   216,
#   66,
#   19,
#   2,
#   48,
#   494,
#   1406,
#   16,
#   8,
#   198,
#   99,
#   38,
#   48,
#   80,
#   100,
#   272,
#   96,
#   5,
#   1084,
#   6,
#   23,
#   28,
#   4189,
#   60,
#   5,
#   1002,
#   171,
#   28,
#   1,
#   252,
#   107,
#   48,
#   80,
#   14,
#   6,
#   40,
#   190,
#   18,
#   1066,
#   78,
#   374,
#   470,
#   2,
#   8,
#   14,
#   162,
#   6,
#   7,
#   1,
#   542,
#   16,
#   127,
#   74,
#   8,
#   65,
#   614,
#   12,
#   2,
#   67,
#   4,
#   206,
#   2667,
#   2280,
#   4188,
#   2,
#   20,
#   23,
#   1275,
#   200,
#   36,
#   50,
#   190,
#   569,
#   278,
#   3,
#   1953,
#   1,
#   676,
#   2,
#   181,
#   96,
#   59,
#   1066,
#   61,
#   2,
#   55,
#   286,
#   109,
#   1066,
#   78,
#   10,
#   18,
#   6269,
#   6270,
#   8,
#   314,
#   1,
#   642,
#   3,
#   607,
#   914,
#   13,
#   9,
#   5,
#   612,
#   1394,
#   675,
#   675,
#   44,
#   1747,
#   8,
#   402,
#   2668,
#   41,
#   641,
#   2,
#   8,
#   747,
#   3,
#   6271,
#   2,
#   8,
#   280,
#   206,
#   30,
#   10,
#   1502,
#   4190,
#   2,
#   48,
#   80,
#   448,
#   2,
#   20,
#   6272,
#   383,
#   1,
#   2281,
#   13,
#   9,
#   7,
#   4191,
#   1568,
#   4191,
#   26,
#   5,
#   1984,
#   1407,
#   6273,
#   1017,
#   59,
#   93,
#   537,
#   65,
#   402,
#   354,
#   1,
#   2176,
#   43,
#   29,
#   288,
#   20,
#   65,
#   10,
#   63,
#   1177,
#   12,
#   121,
#   29,
#   10,
#   999,
#   114,
#   13,
#   9,
#   47,
#   2669,
#   40,
#   10,
#   440,
#   12,
#   19,
#   1,
#   6274,
#   2,
#   40,
#   33,
#   1,
#   2282,
#   92,
#   188,
#   78,
#   20,
#   87,
#   166,
#   254,
#   21,
#   169,
#   103,
#   27,
#   24,
#   20,
#   23,
#   30,
#   13,
#   9,
#   24,
#   45,
#   190,
#   17,
#   162,
#   20,
#   17,
#   316,
#   3,
#   4192,
#   8,
#   67,
#   2,
#   33,
#   99,
#   1166,
#   29,
#   1,
#   220,
#   4,
#   27,
#   100,
#   70,
#   190,
#   35,
#   733,
#   3,
#   1018,
#   64,
#   2177,
#   31,
#   5,
#   1073,
#   1,
#   1189,
#   6275,
#   1985,
#   4193,
#   7,
#   64,
#   465,
#   26,
#   3231,
#   4194,
#   2,
#   33,
#   695,
#   4,
#   96,
#   20,
#   80,
#   20,
#   18,
#   271,
#   68,
#   625,
#   3117,
#   2,
#   16,
#   19,
#   2,
#   16,
#   836,
#   2,
#   870,
#   20,
#   49,
#   8,
#   258,
#   40,
#   120,
#   342,
#   19,
#   1018,
#   118,
#   65,
#   10,
#   108,
#   3,
#   342,
#   12,
#   89,
#   69,
#   615,
#   16,
#   29,
#   1,
#   220,
#   4,
#   1,
#   170,
#   197,
#   70,
#   8,
#   564,
#   6,
#   385,
#   4,
#   190,
#   23,
#   1953,
#   1,
#   284,
#   3,
#   1523,
#   2174,
#   6276,
#   19,
#   64,
#   6277,
#   6,
#   74,
#   5,
#   592,
#   619,
#   4,
#   242,
#   49,
#   139,
#   89,
#   1986,
#   575,
#   3,
#   1987,
#   6278,
#   7,
#   1166,
#   16,
#   1986,
#   419,
#   46,
#   5,
#   312,
#   8,
#   80,
#   397,
#   30,
#   12,
#   37,
#   1981,
#   20,
#   80,
#   120,
#   93,
#   97,
#   110,
#   66,
#   3,
#   2283,
#   5,
#   268,
#   6279,
#   4,
#   575,
#   242,
#   498,
#   7,
#   1981,
#   16,
#   7,
#   2670,
#   8,
#   1168,
#   436,
#   5,
#   2254,
#   6280,
#   2,
#   829,
#   3,
#   1986,
#   8,
#   211,
#   3,
#   768,
#   1,
#   1898,
#   4,
#   1,
#   243,
#   ...],
#  [38,
#   18,
#   85,
#   134,
#   4216,
#   99,
#   1,
#   150,
#   630,
#   25,
#   587,
#   1102,
#   31,
#   1569,
#   31,
#   1,
#   2679,
#   1752,
#   11,
#   17,
#   329,
#   19,
#   972,
#   142,
#   4217,
#   70,
#   665,
#   105,
#   42,
#   6342,
#   119,
#   26,
#   67,
#   27,
#   6,
#   56,
#   51,
#   722,
#   252,
#   2288,
#   3243,
#   56,
#   85,
#   2289,
#   3,
#   42,
#   4218,
#   2,
#   255,
#   15,
#   1,
#   112,
#   176,
#   42,
#   1412,
#   79,
#   32,
#   139,
#   3,
#   816,
#   21,
#   24,
#   13,
#   221,
#   35,
#   161,
#   329,
#   21,
#   1,
#   234,
#   6343,
#   4,
#   550,
#   31,
#   51,
#   4219,
#   56,
#   1,
#   1753,
#   1,
#   234,
#   1753,
#   110,
#   1151,
#   10,
#   991,
#   29,
#   4220,
#   2,
#   1413,
#   89,
#   6344,
#   31,
#   6345,
#   134,
#   36,
#   142,
#   26,
#   3244,
#   2680,
#   1023,
#   1174,
#   26,
#   17,
#   364,
#   5,
#   124,
#   117,
#   29,
#   24,
#   8,
#   312,
#   1,
#   431,
#   698,
#   26,
#   1,
#   150,
#   143,
#   1362,
#   4,
#   133,
#   20,
#   1016,
#   6,
#   13,
#   9,
#   113,
#   5,
#   6346,
#   1024,
#   4,
#   133,
#   21,
#   22,
#   189,
#   4221,
#   31,
#   128,
#   37,
#   4220,
#   31,
#   4222,
#   9,
#   37,
#   1993,
#   2,
#   20,
#   17,
#   1093,
#   26,
#   11,
#   171,
#   33,
#   28,
#   1093,
#   54,
#   30,
#   11,
#   140,
#   13,
#   74,
#   54,
#   30,
#   11,
#   192,
#   12,
#   2681,
#   24,
#   9,
#   1,
#   1994,
#   124,
#   1753,
#   15,
#   6347,
#   545,
#   1,
#   150,
#   201,
#   2218,
#   2,
#   998,
#   27,
#   13,
#   1390,
#   2,
#   8,
#   18,
#   139,
#   3,
#   181,
#   6,
#   5,
#   57,
#   1994,
#   1753,
#   15,
#   3245,
#   9,
#   5,
#   2682,
#   26,
#   1,
#   2683,
#   4223,
#   4,
#   1,
#   177,
#   2290,
#   1414,
#   72,
#   89,
#   1995,
#   4224,
#   2,
#   3246,
#   550,
#   32,
#   29,
#   33,
#   31,
#   6348,
#   550,
#   31,
#   970,
#   2,
#   793,
#   24,
#   13,
#   970,
#   9,
#   32,
#   15,
#   1,
#   1570,
#   191,
#   12,
#   356,
#   53,
#   112,
#   36,
#   99,
#   536,
#   152,
#   195,
#   17,
#   236,
#   4225,
#   236,
#   3247,
#   236,
#   2221,
#   11,
#   2291,
#   3,
#   58,
#   6349,
#   57,
#   105,
#   3248,
#   75,
#   4,
#   1,
#   976,
#   130,
#   114,
#   35,
#   6350,
#   9,
#   32,
#   24,
#   8,
#   2684,
#   794,
#   46,
#   8,
#   139,
#   37,
#   5,
#   187,
#   522,
#   4,
#   6351,
#   31,
#   8,
#   14,
#   4226,
#   34,
#   658,
#   4227,
#   55,
#   8,
#   65,
#   1245,
#   62,
#   7,
#   1,
#   673,
#   34,
#   106,
#   473,
#   1996,
#   65,
#   33,
#   28,
#   1181,
#   2,
#   8,
#   109,
#   1571,
#   8,
#   228,
#   355,
#   34,
#   2292,
#   83,
#   66,
#   3,
#   271,
#   5,
#   6352,
#   234,
#   2293,
#   25,
#   52,
#   6,
#   8,
#   300,
#   113,
#   6353,
#   7,
#   1,
#   508,
#   4,
#   34,
#   189,
#   431,
#   698,
#   8,
#   1016,
#   115,
#   154,
#   85,
#   1368,
#   8,
#   18,
#   245,
#   5,
#   693,
#   341,
#   4,
#   6354,
#   2,
#   115,
#   1025,
#   6,
#   55,
#   110,
#   354,
#   6355,
#   31,
#   3249,
#   3,
#   212,
#   29,
#   12,
#   37,
#   1,
#   427,
#   633,
#   6356,
#   10,
#   1016,
#   110,
#   161,
#   562,
#   26,
#   246,
#   130,
#   57,
#   16,
#   6357,
#   358,
#   80,
#   12,
#   621,
#   5,
#   187,
#   74,
#   3,
#   271,
#   6358,
#   82,
#   98,
#   3,
#   6359,
#   3245,
#   753,
#   120,
#   93,
#   1997,
#   6,
#   12,
#   23,
#   28,
#   5,
#   74,
#   4,
#   6360,
#   2,
#   925,
#   75,
#   4,
#   12,
#   9,
#   5,
#   444,
#   4,
#   6361,
#   75,
#   4,
#   12,
#   753,
#   9,
#   1988,
#   39,
#   431,
#   4,
#   12,
#   7,
#   165,
#   9,
#   1988,
#   2,
#   38,
#   475,
#   104,
#   11,
#   23,
#   30,
#   27,
#   6,
#   25,
#   6,
#   221,
#   6,
#   4228,
#   4,
#   54,
#   90,
#   11,
#   30,
#   7,
#   1,
#   431,
#   698,
#   11,
#   23,
#   30,
#   94,
#   27,
#   35,
#   66,
#   3,
#   2685,
#   24,
#   11,
#   23,
#   30,
#   3,
#   95,
#   45,
#   2289,
#   70,
#   68,
#   928,
#   2,
#   140,
#   61,
#   3,
#   95,
#   5,
#   6362,
#   193,
#   46,
#   114,
#   94,
#   27,
#   1,
#   2682,
#   59,
#   238,
#   924,
#   41,
#   51,
#   6363,
#   1753,
#   15,
#   4229,
#   519,
#   1,
#   165,
#   6,
#   134,
#   4229,
#   17,
#   2294,
#   60,
#   6364,
#   4230,
#   31,
#   10,
#   238,
#   63,
#   1,
#   722,
#   76,
#   4231,
#   19,
#   5,
#   2607,
#   1158,
#   4232,
#   1,
#   252,
#   1158,
#   4,
#   4233,
#   4232,
#   221,
#   6,
# ...
#   2,
#   812,
#   2,
#   6,
#   87,
#   682,
#   62,
#   69,
#   2109,
#   2,
#   12,
#   752,
#   254,
#   230,
#   4,
#   44,
#   66,
#   116,
#   7,
#   11880,
#   4181,
#   40,
#   12,
#   1539,
#   94,
#   26,
#   10,
#   36,
#   58,
#   6,
#   52,
#   22,
#   162,
#   11881,
#   22,
#   825,
#   116,
#   34,
#   549,
#   3,
#   682,
#   62,
#   116,
#   46,
#   214,
#   58,
#   214,
#   26,
#   355,
#   71,
#   2939,
#   34,
#   2529,
#   3943,
#   20,
#   2939,
#   34,
#   2529,
#   3943,
#   82,
#   1056,
#   5762,
#   93,
#   5762,
#   22,
#   5,
#   199,
#   22,
#   1553,
#   58,
#   1,
#   3995,
#   333,
#   20,
#   82,
#   1056,
#   27,
#   12,
#   22,
#   11882,
#   6,
#   73,
#   68,
#   3458,
#   90,
#   44,
#   145,
#   75,
#   11883,
#   77,
#   451,
#   8,
#   82,
#   63,
#   40,
#   10,
#   58,
#   26,
#   16,
#   8,
#   145,
#   5,
#   898,
#   4,
#   2529,
#   3943,
#   38,
#   8,
#   145,
#   75,
#   11884,
#   214,
#   44,
#   11885,
#   12,
#   29,
#   6,
#   58,
#   40,
#   12,
#   11886,
#   62,
#   384,
#   529,
#   16,
#   26,
#   90,
#   440,
#   6,
#   15,
#   380,
#   176,
#   4,
#   1,
#   1494,
#   14,
#   235,
#   5,
#   195,
#   11887,
#   3730,
#   113,
#   1,
#   1501,
#   19,
#   555,
#   14,
#   1984,
#   391,
#   2,
#   56,
#   455,
#   21,
#   5,
#   135,
#   4,
#   231,
#   144,
#   33,
#   8,
#   67,
#   271,
#   230,
#   4,
#   3548,
#   11888,
#   2,
#   67,
#   6,
#   11889,
#   9,
#   289,
#   25,
#   1,
#   11890,
#   161,
#   444,
#   222,
#   203,
#   199,
#   1,
#   11891,
#   6,
#   144,
#   85,
#   235,
#   15,
#   5,
#   898,
#   4,
#   70,
#   22,
#   5,
#   715,
#   11892,
#   199,
#   3,
#   92,
#   7,
#   1505,
#   4,
#   5386,
#   26,
#   212,
#   29,
#   5763,
#   15,
#   3030,
#   25,
#   11,
#   49,
#   3,
#   95,
#   12,
#   1984,
#   2328,
#   104,
#   57,
#   2328,
#   105,
#   1,
#   231,
#   11,
#   257,
#   7,
#   42,
#   2899,
#   19,
#   555,
#   6,
#   199,
#   9,
#   5,
#   5760,
#   1200,
#   5706,
#   12,
#   23,
#   5551,
#   5,
#   11893,
#   3129,
#   1,
#   199,
#   79,
#   499,
#   1501,
#   12,
#   23,
#   3060,
#   552,
#   99,
#   23,
#   73,
#   552,
#   89,
#   1343,
#   1001,
#   23,
#   92,
#   3703,
#   60,
#   552,
#   11894,
#   11895,
#   451,
#   16,
#   22,
#   162,
#   499,
#   11896,
#   38,
#   5,
#   4594,
#   648,
#   12,
#   5,
#   2020,
#   3,
#   92,
#   3703,
#   2,
#   12,
#   194,
#   6,
#   14,
#   32,
#   5,
#   2329,
#   11897,
#   52,
#   22,
#   66,
#   3,
#   615,
#   254,
#   2,
#   1,
#   174,
#   5733,
#   15,
#   45,
#   231,
#   68,
#   14,
#   4797,
#   11898,
#   11,
#   49,
#   1,
#   231,
#   141,
#   29,
#   1,
#   76,
#   1734,
#   653,
#   658,
#   6,
#   1326,
#   494,
#   30,
#   5,
#   135,
#   7,
#   1,
#   2030,
#   3041,
#   5509,
#   96,
#   35,
#   44,
#   227,
#   26,
#   38,
#   14,
#   299,
#   287,
#   3,
#   30,
#   25,
#   11,
#   119,
#   92,
#   89,
#   33,
#   1,
#   2613,
#   386,
#   6,
#   49,
#   85,
#   11899,
#   2,
#   11900,
#   15,
#   295,
#   11901,
#   7,
#   1,
#   386,
#   6,
#   35,
#   227,
#   855,
#   3,
#   92,
#   89,
#   214,
#   350,
#   13,
#   505,
#   5431,
#   11902,
#   2157,
#   17,
#   1188,
#   3,
#   1229,
#   1,
#   11903,
#   696,
#   11904,
#   11905,
#   79,
#   6,
#   186,
#   11906,
#   11907,
#   23,
#   11,
#   18,
#   203,
#   39,
#   4,
#   45,
#   451,
#   131,
#   16,
#   13,
#   9,
#   5,
#   11908,
#   71,
#   49,
#   282,
#   5,
#   199,
#   100,
#   411,
#   4893,
#   215,
#   3901,
#   231,
#   89,
#   5763,
#   212,
#   29,
#   216,
#   66,
#   19,
#   1,
#   231,
#   148,
#   996,
#   3763,
#   1,
#   1411,
#   107,
#   56,
#   241,
#   7,
#   1,
#   4492,
#   16,
#   392,
#   14,
#   39,
#   4,
#   1,
#   231,
#   2098,
#   141,
#   2707,
#   11909,
#   39,
#   201,
#   153,
#   1,
#   72,
#   715,
#   156,
#   18,
#   45,
#   231,
#   52,
#   129,
#   19,
#   1485,
#   3029,
#   7,
#   680,
#   127,
#   151,
#   2,
#   56,
#   39,
#   4,
#   1,
#   690,
#   20,
#   ...],
#  [13,
#   9,
#   5,
#   1346,
#   8,
#   183,
#   59,
#   9,
#   5,
#   97,
#   4,
#   132,
#   4,
#   11986,
#   5,
#   708,
#   89,
#   51,
#   1672,
#   6,
#   79,
#   128,
#   1117,
#   4,
#   730,
#   16,
#   12,
#   23,
#   1353,
#   19,
#   5,
#   273,
#   13,
#   9,
#   5,
#   3946,
#   1004,
#   51,
#   3685,
#   417,
#   77,
#   2,
#   78,
#   13,
#   5767,
#   5768,
#   2,
#   1,
#   5767,
#   5768,
#   14,
#   68,
#   228,
#   27,
#   31,
#   94,
#   6,
#   1036,
#   98,
#   3,
#   1038,
#   19,
#   3,
#   2,
#   6,
#   65,
#   3801,
#   2608,
#   136,
#   69,
#   548,
#   1,
#   3685,
#   9,
#   50,
#   22,
#   47,
#   699,
#   1,
#   3946,
#   9,
#   584,
#   326,
#   4424,
#   1899,
#   6,
#   88,
#   1959,
#   19,
#   1,
#   749,
#   354,
#   4,
#   1,
#   3946,
#   1004,
#   120,
#   5,
#   1442,
#   2341,
#   6,
#   9,
#   5769,
#   19,
#   51,
#   4366,
#   56,
#   19,
#   100,
#   11987,
#   6,
#   863,
#   7,
#   224,
#   383,
#   12,
#   41,
#   13,
#   6,
#   11988,
#   13,
#   2341,
#   16,
#   12,
#   1957,
#   12,
#   3,
#   1959,
#   2,
#   1,
#   5770,
#   79,
#   6,
#   1353,
#   1062,
#   6,
#   12,
#   225,
#   230,
#   4,
#   2798,
#   161,
#   2,
#   301,
#   1,
#   137,
#   37,
#   127,
#   919,
#   25,
#   40,
#   10,
#   145,
#   94,
#   19,
#   269,
#   4,
#   12,
#   12,
#   11989,
#   12,
#   2,
#   16,
#   12,
#   65,
#   3112,
#   99,
#   25,
#   7,
#   13,
#   497,
#   50,
#   1,
#   3510,
#   9,
#   5769,
#   7,
#   11990,
#   3,
#   1,
#   5770,
#   12,
#   23,
#   864,
#   62,
#   19,
#   39,
#   273,
#   2,
#   78,
#   38,
#   14,
#   5,
#   252,
#   666,
#   3,
#   13,
#   1672,
#   59,
#   9,
#   6,
#   12,
#   26,
#   8,
#   211,
#   12,
#   3,
#   3939,
#   75,
#   11991,
#   6,
#   8,
#   14,
#   1249,
#   7,
#   59,
#   9,
#   1,
#   1577,
#   4,
#   1,
#   500,
#   2,
#   1,
#   1577,
#   4,
#   1,
#   512,
#   7,
#   1647,
#   3,
#   169,
#   11992,
#   14,
#   2693,
#   68,
#   845,
#   19,
#   2412,
#   3,
#   95,
#   96,
#   3655,
#   7,
#   1,
#   404,
#   2,
#   8,
#   228,
#   62,
#   5,
#   135,
#   4,
#   938,
#   13,
#   9,
#   1346,
#   6,
#   8,
#   183,
#   6,
#   26,
#   22,
#   5771,
#   11993,
#   1,
#   107,
#   9,
#   9,
#   6,
#   22,
#   1301,
#   855,
#   1083,
#   22,
#   230,
#   4,
#   11994,
#   254,
#   55,
#   22,
#   7,
#   5,
#   2753,
#   25,
#   22,
#   3022,
#   26,
#   214,
#   58,
#   40,
#   8,
#   23,
#   5705,
#   12,
#   5,
#   81,
#   210,
#   360,
#   5199,
#   26,
#   5700,
#   16,
#   13,
#   9,
#   44,
#   1888,
#   1888,
#   19,
#   5,
#   2994,
#   2236,
#   542,
#   59,
#   11995,
#   12,
#   7,
#   33,
#   3099,
#   920,
#   38,
#   9,
#   5,
#   5158,
#   5772,
#   77,
#   59,
#   1862,
#   12,
#   37,
#   66,
#   99,
#   1,
#   269,
#   4,
#   22,
#   542,
#   22,
#   230,
#   4,
#   3877,
#   19,
#   5,
#   2236,
#   542,
#   29,
#   1,
#   4485,
#   4,
#   5,
#   3494,
#   2,
#   56,
#   24,
#   2536,
#   1,
#   1672,
#   2,
#   1862,
#   12,
#   11996,
#   67,
#   11,
#   88,
#   1959,
#   1,
#   11997,
#   11998,
#   8,
#   18,
#   5,
#   230,
#   4,
#   5,
#   5537,
#   4,
#   2890,
#   6,
#   8,
#   314,
#   4,
#   128,
#   4261,
#   59,
#   8,
#   88,
#   11999,
#   13,
#   9,
#   5,
#   1346,
#   4,
#   1,
#   756,
#   2,
#   1,
#   512,
#   7,
#   1647,
#   2373,
#   6,
#   628,
#   2,
#   5,
#   370,
#   595,
#   6,
#   12,
#   621,
#   699,
#   2,
#   3947,
#   3,
#   953,
#   1,
#   100,
#   16,
#   77,
#   9,
#   1,
#   512,
#   22,
#   5,
#   81,
#   236,
#   105,
#   5,
#   3287,
#   6,
#   14,
#   574,
#   4,
#   2755,
#   12000,
#   77,
#   9,
#   5,
#   952,
#   1346,
#   56,
#   1,
#   756,
#   29,
#   6,
#   220,
#   2,
#   78,
#   7,
#   5,
#   1482,
#   4,
#   12001,
#   5473,
#   12,
#   3586,
#   5773,
#   26,
#   169,
#   1004,
#   2,
#   1,
#   980,
#   224,
#   61,
#   1229,
#   5773,
#   357,
#   20,
#   73,
#   141,
#   3,
#   13,
#   81,
#   512,
#   13,
#   9,
#   7,
#   5,
#   1346,
#   760,
#   7,
#   12002,
#   39,
#   9,
#   27,
#   1,
#   500,
#   2,
#   78,
#   1,
#   1182,
#   3,
#   1,
#   512,
#   7,
#   1647,
#   125,
#   13,
#   9,
#   5,
#   81,
#   1603,
#   1004,
#   1888,
#   31,
#   10,
#   23,
#   58,
#   1,
#   81,
#   5772,
#   6,
#   22,
#   125,
#   5771,
#   12003,
#   78,
#   13,
#   9,
#   1,
#   106,
#   176,
#   4,
#   26,
#   13,
#   9,
#   5774,
#   1838,
#   413,
#   1,
#   756,
#   9,
#   5774,
#   313,
#   1,
#   1577,
#   4,
#   1,
#   512,
#   2,
#   16,
#   13,
#   9,
#   1,
#   480,
#   4,
#   1,
#   756,
#   2,
#   78,
#   169,
#   4,
#   45,
#   81,
#   1838,
#   9,
#   1,
#   480,
#   4,
#   1,
#   512,
#   7,
#   1647,
#   3,
#   1,
#   756,
#   22,
#   183,
#   62,
#   4,
#   2737,
#   12004,
#   3288,
#   169,
#   39,
#   79,
#   12005,
#   1838,
#   13,
#   9,
#   7,
#   1,
#   12006,
#   4,
#   5,
#   12007,
#   5775,
#   8,
#   14,
#   253,
#   6,
#   1,
#   756,
#   9,
#   132,
#   4,
#   1,
#   1686,
#   5775,
#   16,
#   13,
#   172,
#   9,
#   19,
#   1,
#   1390,
#   26,
#   5,
#   1711,
#   37,
#   1,
#   12008,
#   4,
#   1,
#   512,
#   2,
#   78,
#   1,
#   500,
#   7,
#   1,
#   653,
#   2,
#   22,
#   1888,
#   2,
#   13,
#   9,
#   7,
#   12009,
#   9,
#   7,
#   12010,
#   22,
#   5045,
#   19,
#   5,
#   12011,
#   2,
#   5,
#   1004,
#   101,
#   29,
#   1,
#   653,
#   4,
#   3947,
#   43,
#   44,
#   1301,
#   1430,
#   1,
#   653,
#   4,
#   3947,
#   59,
#   221,
#   6,
#   1,
#   1107,
#   370,
#   4,
#   1,
#   1672,
#   9,
#   44,
#   5,
#   81,
#   210,
#   57,
#   12012,
#   16,
#   10,
#   23,
#   58,
#   12,
#   12013,
#   77,
#   12,
#   1633,
#   27,
#   5,
#   5776,
#   43,
#   99,
#   5,
#   5776,
#   22,
#   183,
#   4,
#   12014,
#   5750,
#   337,
#   2761,
#   25,
#   22,
#   148,
#   12015,
#   41,
#   6,
#   7,
#   12016,
#   22,
#   5298,
#   3,
#   1611,
#   60,
#   1,
#   404,
#   12017,
#   9,
#   203,
#   589,
#   4,
#   138,
#   6,
#   8,
#   30,
#   45,
#   17,
#   45,
#   12018,
#   45,
#   1838,
#   17,
#   33,
#   12019,
#   25,
#   20,
#   18,
#   12020,
#   12021,
#   7,
#   61,
#   6,
#   95,
#   61,
#   33,
#   41,
#   12022,
#   16,
#   33,
#   1,
#   679,
#   1645,
#   15,
#   196,
#   327,
#   39,
#   919,
#   607,
#   2,
#   1,
#   710,
#   251,
#   1,
#   5218,
#   1335,
#   1,
#   103,
#   97,
#   16,
#   31,
#   10,
#   371,
#   116,
#   110,
#   452,
#   128,
#   12023,
#   9,
#   524,
#   19,
#   1,
#   944,
#   4,
#   5,
#   5777,
#   12,
#   14,
#   5,
#   5777,
#   930,
#   944,
#   14,
#   1,
#   273,
#   4,
#   12024,
#   2,
#   78,
#   38,
#   35,
#   132,
#   4,
#   592,
#   980,
#   7,
#   1,
#   12025,
#   224,
#   1,
#   2708,
#   2,
#   16,
#   8,
#   2175,
#   39,
#   57,
#   2958,
#   4,
#   169,
#   39,
#   4,
#   61,
#   45,
#   35,
#   571,
#   1838,
#   78,
#   8,
#   49,
#   505,
#   12026,
#   6,
#   35,
#   12027,
#   12028,
#   459,
#   1,
#   1838,
#   16,
#   20,
#   65,
#   1278,
#   810,
#   4,
#   1,
#   1008,
#   2,
#   95,
#   230,
#   4,
#   2718,
#   2047,
#   2868,
#   31,
#   10,
#   560,
#   136,
#   12,
#   136,
#   1,
#   12029,
#   9,
#   94,
#   8,
#   119,
#   4,
#   5,
#   5778,
#   1343,
#   243,
#   12,
#   14,
#   1,
#   185,
#   4,
#   5327,
#   1,
#   5778,
#   3524,
#   4,
#   1346,
#   2,
#   78,
#   691,
#   12,
#   89,
#   5,
#   1343,
#   243,
#   13,
#   9,
#   51,
#   185,
#   4,
#   535,
#   5,
#   1346,
#   5,
#   1004,
#   6,
#   65,
#   28,
#   12030,
#   116,
#   1,
#   281,
#   60,
#   5,
#   12031,
#   9,
#   5,
#   650,
#   8,
#   1279,
#   12,
#   79,
#   3940,
#   5779,
#   12032,
#   748,
#   4199,
#   77,
#   12,
#   356,
#   358,
#   814,
#   151,
#   7,
#   12033,
#   21,
#   1,
#   12034,
#   78,
#   13,
#   9,
#   41,
#   772,
#   6,
#   17,
#   926,
#   3,
#   257,
#   13,
#   79,
#   5,
#   12035,
#   2158,
#   16,
#   22,
#   5,
#   1888,
#   1772,
#   21,
#   126,
#   2366,
#   126,
#   6,
#   23,
#   921,
#   37,
#   217,
#   3,
#   217,
#   13,
#   65,
#   28,
#   2801,
#   8,
#   2356,
#   21,
#   12036,
#   7,
#   1,
#   244,
#   12037,
#   1,
#   285,
#   4,
#   162,
#   34,
#   138,
#   8,
#   230,
#   4,
#   18,
#   5,
#   3011,
#   1001,
#   4,
#   2421,
#   2,
#   75,
#   4,
#   12,
#   9,
#   44,
#   1,
#   185,
#   4,
#   745,
#   605,
#   26,
#   605,
#   31,
#   5,
#   1346,
#   94,
#   ...],
#  [12065,
#   1651,
#   5781,
#   9,
#   34,
#   846,
#   2132,
#   2188,
#   12,
#   221,
#   3,
#   402,
#   3732,
#   40,
#   110,
#   531,
#   5,
#   2132,
#   12066,
#   2,
#   10,
#   797,
#   5,
#   5781,
#   7,
#   1,
#   2287,
#   10,
#   108,
#   3,
#   402,
#   5782,
#   100,
#   3948,
#   26,
#   130,
#   5782,
#   197,
#   3948,
#   26,
#   1137,
#   2893,
#   13,
#   9,
#   34,
#   2514,
#   4,
#   5,
#   12067,
#   59,
#   4600,
#   93,
#   444,
#   54,
#   134,
#   496,
#   1103,
#   496,
#   4,
#   3948,
#   38,
#   238,
#   28,
#   511,
#   154,
#   1100,
#   1223,
#   2617,
#   56,
#   34,
#   1053,
#   2393,
#   4,
#   2617,
#   5,
#   47,
#   12068,
#   12069,
#   41,
#   3,
#   428,
#   5,
#   81,
#   210,
#   27,
#   1,
#   506,
#   4,
#   1504,
#   1045,
#   405,
#   764,
#   1976,
#   5,
#   210,
#   4,
#   34,
#   189,
#   2354,
#   1534,
#   1045,
#   405,
#   14,
#   681,
#   3,
#   989,
#   554,
#   1,
#   845,
#   12070,
#   2,
#   31,
#   74,
#   198,
#   60,
#   12071,
#   21,
#   499,
#   1876,
#   12,
#   3146,
#   89,
#   1,
#   405,
#   11,
#   63,
#   142,
#   31,
#   764,
#   16,
#   12,
#   79,
#   5,
#   506,
#   4,
#   27,
#   780,
#   12072,
#   14,
#   1151,
#   1381,
#   2,
#   8,
#   14,
#   1085,
#   3,
#   208,
#   6,
#   331,
#   343,
#   5,
#   176,
#   4,
#   34,
#   133,
#   2,
#   8,
#   2406,
#   12,
#   3,
#   28,
#   455,
#   255,
#   8,
#   1016,
#   52,
#   6,
#   6,
#   343,
#   1,
#   497,
#   29,
#   33,
#   331,
#   14,
#   47,
#   104,
#   5,
#   176,
#   4,
#   34,
#   133,
#   68,
#   19,
#   34,
#   416,
#   127,
#   151,
#   31,
#   5,
#   1381,
#   315,
#   329,
#   7,
#   5,
#   76,
#   4,
#   331,
#   22,
#   31,
#   40,
#   8,
#   14,
#   329,
#   7,
#   5,
#   1288,
#   441,
#   12073,
#   825,
#   22,
#   1217,
#   12074,
#   5419,
#   2,
#   12075,
#   360,
#   277,
#   12076,
#   2625,
#   54,
#   9,
#   12,
#   6,
#   8,
#   259,
#   331,
#   90,
#   8,
#   614,
#   54,
#   36,
#   2786,
#   2,
#   1761,
#   3,
#   331,
#   10,
#   36,
#   17,
#   41,
#   34,
#   12077,
#   2,
#   3309,
#   331,
#   8,
#   278,
#   2,
#   2082,
#   6,
#   854,
#   29,
#   1,
#   137,
#   74,
#   115,
#   460,
#   6,
#   8,
#   256,
#   331,
#   2,
#   115,
#   282,
#   54,
#   36,
#   1761,
#   3,
#   46,
#   3787,
#   115,
#   460,
#   15,
#   196,
#   82,
#   12078,
#   1,
#   1968,
#   82,
#   95,
#   227,
#   104,
#   1434,
#   55,
#   110,
#   2504,
#   37,
#   1,
#   12079,
#   12080,
#   12081,
#   2,
#   55,
#   110,
#   2504,
#   95,
#   353,
#   10,
#   82,
#   12082,
#   69,
#   12083,
#   19,
#   1,
#   1764,
#   33,
#   4,
#   45,
#   96,
#   8,
#   1420,
#   331,
#   5783,
#   246,
#   8,
#   67,
#   27,
#   331,
#   5783,
#   57,
#   105,
#   1,
#   972,
#   1077,
#   315,
#   194,
#   83,
#   12084,
#   116,
#   331,
#   2,
#   83,
#   225,
#   1216,
#   7,
#   4126,
#   2331,
#   12085,
#   116,
#   331,
#   27,
#   216,
#   3,
#   139,
#   12086,
#   13,
#   2514,
#   12087,
#   3,
#   28,
#   564,
#   12088,
#   3,
#   28,
#   3214,
#   12089,
#   3,
#   28,
#   3858,
#   2,
#   10,
#   797,
#   1,
#   1203,
#   26,
#   38,
#   17,
#   93,
#   1901,
#   3415,
#   7,
#   1,
#   986,
#   56,
#   50,
#   1,
#   986,
#   265,
#   2330,
#   331,
#   136,
#   1,
#   3111,
#   12090,
#   2,
#   12091,
#   1381,
#   1412,
#   1133,
#   9,
#   1298,
#   3,
#   331,
#   13,
#   9,
#   5,
#   1045,
#   15,
#   1203,
#   7,
#   764,
#   5,
#   1933,
#   1203,
#   5227,
#   240,
#   986,
#   255,
#   15,
#   46,
#   12092,
#   12,
#   21,
#   34,
#   2336,
#   3591,
#   62,
#   41,
#   6,
#   218,
#   152,
#   871,
#   56,
#   118,
#   511,
#   797,
#   7,
#   34,
#   5754,
#   8,
#   1950,
#   3,
#   197,
#   986,
#   19,
#   12093,
#   1,
#   201,
#   3523,
#   8,
#   49,
#   1,
#   861,
#   3,
#   1406,
#   3,
#   5211,
#   2829,
#   15,
#   51,
#   5221,
#   12094,
#   38,
#   4013,
#   3,
#   13,
#   74,
#   8,
#   49,
#   85,
#   339,
#   31,
#   5,
#   5660,
#   554,
#   13,
#   1451,
#   8,
#   2799,
#   128,
#   5738,
#   2,
#   12095,
#   980,
#   2,
#   31,
#   8,
#   198,
#   37,
#   39,
#   217,
#   3,
#   1,
#   170,
#   8,
#   1191,
#   38,
#   14,
#   93,
#   740,
#   844,
#   38,
#   29,
#   6,
#   74,
#   331,
#   14,
#   12096,
#   2,
#   13,
#   4682,
#   46,
#   38,
#   14,
#   93,
#   740,
#   844,
#   289,
#   14,
#   12097,
#   331,
#   79,
#   139,
#   89,
#   34,
#   844,
#   2770,
#   9,
#   12,
#   66,
#   3,
#   773,
#   1182,
#   46,
#   37,
#   844,
#   8,
#   566,
#   6,
#   218,
#   18,
#   3,
#   28,
#   1,
#   497,
#   29,
#   33,
#   8,
#   113,
#   63,
#   331,
#   8,
#   63,
#   12,
#   16,
#   90,
#   6,
#   12,
#   218,
#   18,
#   3,
#   28,
#   94,
#   44,
#   931,
#   136,
#   1,
#   1714,
#   12,
#   88,
#   28,
#   510,
#   12098,
#   43,
#   931,
#   31,
#   5,
#   740,
#   43,
#   130,
#   31,
#   51,
#   4349,
#   8,
#   564,
#   3,
#   12099,
#   5332,
#   4,
#   331,
#   2,
#   3,
#   145,
#   12,
#   89,
#   34,
#   844,
#   1408,
#   2,
#   289,
#   6,
#   8,
#   49,
#   85,
#   1085,
#   3928,
#   331,
#   8,
#   564,
#   3,
#   30,
#   188,
#   21,
#   2,
#   12100,
#   8,
#   160,
#   745,
#   5,
#   124,
#   458,
#   4,
#   138,
#   2,
#   55,
#   8,
#   2230,
#   13,
#   3,
#   1,
#   844,
#   274,
#   8,
#   14,
#   5128,
#   188,
#   21,
#   1,
#   619,
#   4,
#   546,
#   2,
#   443,
#   8,
#   1398,
#   8,
#   566,
#   331,
#   9,
#   41,
#   242,
#   377,
#   302,
#   26,
#   298,
#   1880,
#   7,
#   1,
#   121,
#   4,
#   34,
#   416,
#   115,
#   225,
#   510,
#   6,
#   331,
#   14,
#   69,
#   107,
#   5,
#   1077,
#   2258,
#   107,
#   2,
#   331,
#   9,
#   16,
#   693,
#   6,
#   12,
#   88,
#   669,
#   12101,
#   46,
#   2,
#   34,
#   12102,
#   43,
#   12,
#   88,
#   5050,
#   46,
#   8,
#   1652,
#   3,
#   28,
#   12103,
#   5,
#   1646,
#   1412,
#   116,
#   3471,
#   405,
#   2,
#   44,
#   50,
#   8,
#   82,
#   140,
#   34,
#   12104,
#   754,
#   3,
#   1280,
#   7,
#   3983,
#   495,
#   22,
#   31,
#   40,
#   8,
#   82,
#   18,
#   5,
#   754,
#   29,
#   33,
#   16,
#   8,
#   108,
#   3,
#   138,
#   21,
#   910,
#   71,
#   23,
#   546,
#   46,
#   31,
#   51,
#   982,
#   2,
#   271,
#   34,
#   754,
#   2,
#   6,
#   97,
#   83,
#   167,
#   3,
#   2301,
#   12105,
#   7,
#   504,
#   2316,
#   29,
#   292,
#   29,
#   138,
#   2,
#   1219,
#   8,
#   138,
#   21,
#   134,
#   128,
#   764,
#   12106,
#   2,
#   64,
#   754,
#   729,
#   34,
#   754,
#   2,
#   2927,
#   20,
#   200,
#   46,
#   3,
#   28,
#   338,
#   2,
#   64,
#   3023,
#   1038,
#   1127,
#   2,
#   1880,
#   12107,
#   60,
#   12108,
#   53,
#   64,
#   3023,
#   83,
#   167,
#   3,
#   2301,
#   5,
#   2362,
#   708,
#   4,
#   1880,
#   132,
#   4,
#   41,
#   364,
#   53,
#   5,
#   3203,
#   21,
#   5,
#   47,
#   439,
#   1066,
#   897,
#   40,
#   8,
#   156,
#   912,
#   13,
#   1408,
#   8,
#   152,
#   6,
#   8,
#   88,
#   44,
#   12109,
#   254,
#   89,
#   12110,
#   2,
#   32,
#   2301,
#   146,
#   708,
#   4,
#   298,
#   12111,
#   21,
#   331,
#   31,
#   34,
#   124,
#   844,
#   2304,
#   8,
#   12112,
#   89,
#   1,
#   76,
#   4,
#   594,
#   2,
#   8,
#   14,
#   1375,
#   3,
#   58,
#   1,
#   12113,
#   224,
#   594,
#   2,
#   764,
#   15,
#   196,
#   5,
#   2132,
#   936,
#   388,
#   28,
#   1157,
#   1723,
#   2,
#   2704,
#   19,
#   636,
#   2,
#   1,
#   137,
#   3046,
#   455,
#   15,
#   5,
#   1387,
#   7,
#   764,
#   129,
#   378,
#   1531,
#   12114,
#   2,
#   1531,
#   12115,
#   26,
#   701,
#   6,
#   3111,
#   659,
#   23,
#   1575,
#   1,
#   722,
#   701,
#   4,
#   378,
#   1876,
#   2,
#   12116,
#   41,
#   3,
#   428,
#   21,
#   10,
#   5,
#   1651,
#   1753,
#   3,
#   18,
#   10,
#   18,
#   5,
#   195,
#   827,
#   4,
#   54,
#   764,
#   365,
#   16,
#   12117,
#   5,
#   1651,
#   764,
#   9,
#   3331,
#   141,
#   89,
#   134,
#   128,
#   5784,
#   5785,
#   40,
#   10,
#   4255,
#   5,
#   128,
#   5081,
#   3,
#   169,
#   1255,
#   31,
#   10,
#   402,
#   1,
#   1651,
#   26,
#   245,
#   31,
#   12118,
#   1989,
#   458,
#   1133,
#   1563,
#   263,
#   1308,
#   2,
#   16,
#   19,
#   31,
#   10,
#   402,
#   1,
#   1651,
#   26,
#   465,
#   9,
#   5,
#   12119,
#   405,
#   31,
#   40,
#   39,
#   622,
#   9,
#   148,
#   12120,
#   29,
#   5,
#   74,
#   818,
#   764,
#   9,
#   57,
#   41,
#   5,
#   3509,
#   26,
#   33,
#   260,
#   1952,
#   108,
#   3,
#   139,
#   141,
#   ...],
#  []]

# %%
def flatten_list(nested_list):
    flattened = []
    for item in nested_list:
        if isinstance(item, list):
            flattened.extend(flatten_list(item))
        else:
            flattened.append(item)
    return flattened


sequence_list = flatten_list(sequence)

# %%
len(sequence_list)
# Out:
# 135982

# %%
sequences = []

for i in range(3, len(sequence_list)):
    words = sequence_list[i-3:i+1]
    sequences.append(words)

print("The Length of sequences are: ", len(sequences))
sequences = np.array(sequences)
sequences[:10]
# Out:
# The Length of sequences are:  135979
# array([[  8,  65,  41,   3],
#        [ 65,  41,   3, 428],
#        [ 41,   3, 428,  21],
#        [  3, 428,  21,  10],
#        [428,  21,  10,   5],
#        [ 21,  10,   5, 124],
#        [ 10,   5, 124, 387],
#        [  5, 124, 387,   4],
#        [124, 387,   4, 418],
#        [387,   4, 418, 374]])

# %%
x = []
y = []

for i in sequences:
    x.append(i[0:3])
    y.append(i[3])

x = np.array(x)
y = np.array(y)

# %%
print("Data: ", x[:10])
print("Response: ", y[:10])
# Out:
# Data:  [[  8  65  41]
#  [ 65  41   3]
#  [ 41   3 428]
#  [  3 428  21]
#  [428  21  10]
#  [ 21  10   5]
#  [ 10   5 124]
#  [  5 124 387]
#  [124 387   4]
#  [387   4 418]]
# Response:  [  3 428  21  10   5 124 387   4 418 374]

# %%
vocab_size = len(token.word_index) + 1
print(vocab_size)
# Out:
# 12153

# %%
y = to_categorical(y, num_classes=vocab_size)

# %%
len(y)
# Out:
# 135979

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((91105, 3), (44874, 3), (91105, 12153), (44874, 12153))

# %%
model1 = Sequential()
model1.add(Embedding(vocab_size, 10, input_length=3))
model1.add(LSTM(100, return_sequences=True))
model1.add(LSTM(100))
model1.add(Dense(100, activation="relu"))
model1.add(Dense(vocab_size, activation="softmax"))

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 3, 10)             121530
#
#  lstm (LSTM)                 (None, 3, 100)            44400
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 12153)             1227453
#
# =================================================================
# Total params: 1,483,883
# Trainable params: 1,483,883
# Non-trainable params: 0
# _________________________________________________________________

# %%
# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10,verbose=1,mode='auto')

# %%
model1.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.001),metrics=["accuracy"])
history = model1.fit(x_train, y_train, epochs=50, validation_split=0.1,batch_size=32)
# Out:
# Epoch 1/50
# 2563/2563 [==============================] - 127s 47ms/step - loss: 6.8623 - accuracy: 0.0459 - val_loss: 6.6535 - val_accuracy: 0.0522
# Epoch 2/50
# 2563/2563 [==============================] - 114s 44ms/step - loss: 6.4394 - accuracy: 0.0652 - val_loss: 6.6041 - val_accuracy: 0.0705
# Epoch 3/50
# 2563/2563 [==============================] - 112s 44ms/step - loss: 6.1283 - accuracy: 0.0829 - val_loss: 6.5982 - val_accuracy: 0.0874
# Epoch 4/50
# 2563/2563 [==============================] - 114s 45ms/step - loss: 5.8954 - accuracy: 0.0982 - val_loss: 6.6452 - val_accuracy: 0.0940
# Epoch 5/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 5.6799 - accuracy: 0.1107 - val_loss: 6.6731 - val_accuracy: 0.0979
# Epoch 6/50
# 2563/2563 [==============================] - 112s 44ms/step - loss: 5.4879 - accuracy: 0.1196 - val_loss: 6.7333 - val_accuracy: 0.1013
# Epoch 7/50
# 2563/2563 [==============================] - 115s 45ms/step - loss: 5.3089 - accuracy: 0.1282 - val_loss: 6.8963 - val_accuracy: 0.1059
# Epoch 8/50
# 2563/2563 [==============================] - 115s 45ms/step - loss: 5.1405 - accuracy: 0.1378 - val_loss: 6.9949 - val_accuracy: 0.1056
# Epoch 9/50
# 2563/2563 [==============================] - 115s 45ms/step - loss: 4.9816 - accuracy: 0.1463 - val_loss: 7.1920 - val_accuracy: 0.1080
# Epoch 10/50
# 2563/2563 [==============================] - 113s 44ms/step - loss: 4.8273 - accuracy: 0.1545 - val_loss: 7.4255 - val_accuracy: 0.1095
# Epoch 11/50
# 2563/2563 [==============================] - 113s 44ms/step - loss: 4.6732 - accuracy: 0.1632 - val_loss: 7.7342 - val_accuracy: 0.1075
# Epoch 12/50
# 2563/2563 [==============================] - 112s 44ms/step - loss: 4.5256 - accuracy: 0.1716 - val_loss: 8.0699 - val_accuracy: 0.1086
# Epoch 13/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 4.3825 - accuracy: 0.1793 - val_loss: 8.4620 - val_accuracy: 0.1066
# Epoch 14/50
# 2563/2563 [==============================] - 108s 42ms/step - loss: 4.2454 - accuracy: 0.1899 - val_loss: 8.9604 - val_accuracy: 0.1054
# Epoch 15/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 4.1175 - accuracy: 0.1974 - val_loss: 9.2893 - val_accuracy: 0.1042
# Epoch 16/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 3.9935 - accuracy: 0.2099 - val_loss: 9.6686 - val_accuracy: 0.1033
# Epoch 17/50
# 2563/2563 [==============================] - 108s 42ms/step - loss: 3.8790 - accuracy: 0.2229 - val_loss: 10.2626 - val_accuracy: 0.0995
# Epoch 18/50
# 2563/2563 [==============================] - 109s 42ms/step - loss: 3.7700 - accuracy: 0.2366 - val_loss: 10.6220 - val_accuracy: 0.0995
# Epoch 19/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 3.6743 - accuracy: 0.2499 - val_loss: 11.0161 - val_accuracy: 0.0986
# Epoch 20/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 3.5817 - accuracy: 0.2635 - val_loss: 11.6996 - val_accuracy: 0.0947
# Epoch 21/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 3.4969 - accuracy: 0.2765 - val_loss: 12.0623 - val_accuracy: 0.0950
# Epoch 22/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 3.4196 - accuracy: 0.2885 - val_loss: 12.5488 - val_accuracy: 0.0915
# Epoch 23/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 3.3500 - accuracy: 0.3001 - val_loss: 12.8727 - val_accuracy: 0.0920
# Epoch 24/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 3.2811 - accuracy: 0.3096 - val_loss: 13.1655 - val_accuracy: 0.0905
# Epoch 25/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 3.2235 - accuracy: 0.3190 - val_loss: 13.3856 - val_accuracy: 0.0892
# Epoch 26/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 3.1642 - accuracy: 0.3286 - val_loss: 13.7769 - val_accuracy: 0.0834
# Epoch 27/50
# 2563/2563 [==============================] - 109s 42ms/step - loss: 3.1121 - accuracy: 0.3362 - val_loss: 14.2338 - val_accuracy: 0.0881
# Epoch 28/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 3.0592 - accuracy: 0.3448 - val_loss: 14.4016 - val_accuracy: 0.0858
# Epoch 29/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 3.0074 - accuracy: 0.3536 - val_loss: 14.9127 - val_accuracy: 0.0864
# Epoch 30/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.9574 - accuracy: 0.3614 - val_loss: 14.7923 - val_accuracy: 0.0835
# Epoch 31/50
# 2563/2563 [==============================] - 109s 42ms/step - loss: 2.9169 - accuracy: 0.3682 - val_loss: 15.1750 - val_accuracy: 0.0858
# Epoch 32/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.8710 - accuracy: 0.3765 - val_loss: 15.5457 - val_accuracy: 0.0840
# Epoch 33/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.8310 - accuracy: 0.3823 - val_loss: 15.7913 - val_accuracy: 0.0846
# Epoch 34/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.7898 - accuracy: 0.3884 - val_loss: 15.9719 - val_accuracy: 0.0833
# Epoch 35/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.7501 - accuracy: 0.3958 - val_loss: 16.3782 - val_accuracy: 0.0841
# Epoch 36/50
# 2563/2563 [==============================] - 108s 42ms/step - loss: 2.7161 - accuracy: 0.4010 - val_loss: 16.5780 - val_accuracy: 0.0825
# Epoch 37/50
# 2563/2563 [==============================] - 108s 42ms/step - loss: 2.6829 - accuracy: 0.4080 - val_loss: 16.9362 - val_accuracy: 0.0837
# Epoch 38/50
# 2563/2563 [==============================] - 109s 43ms/step - loss: 2.6492 - accuracy: 0.4127 - val_loss: 16.6917 - val_accuracy: 0.0798
# Epoch 39/50
# 2563/2563 [==============================] - 109s 42ms/step - loss: 2.6141 - accuracy: 0.4174 - val_loss: 17.4298 - val_accuracy: 0.0826
# Epoch 40/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.5837 - accuracy: 0.4233 - val_loss: 17.6942 - val_accuracy: 0.0795
# Epoch 41/50
# 2563/2563 [==============================] - 109s 42ms/step - loss: 2.5511 - accuracy: 0.4294 - val_loss: 18.2331 - val_accuracy: 0.0826
# Epoch 42/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.5236 - accuracy: 0.4337 - val_loss: 18.0580 - val_accuracy: 0.0799
# Epoch 43/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 2.4962 - accuracy: 0.4389 - val_loss: 18.4734 - val_accuracy: 0.0831
# Epoch 44/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 2.4692 - accuracy: 0.4423 - val_loss: 18.5203 - val_accuracy: 0.0772
# Epoch 45/50
# 2563/2563 [==============================] - 109s 43ms/step - loss: 2.4451 - accuracy: 0.4491 - val_loss: 18.5073 - val_accuracy: 0.0778
# Epoch 46/50
# 2563/2563 [==============================] - 110s 43ms/step - loss: 2.4185 - accuracy: 0.4525 - val_loss: 18.4795 - val_accuracy: 0.0791
# Epoch 47/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 2.3943 - accuracy: 0.4570 - val_loss: 18.8691 - val_accuracy: 0.0773
# Epoch 48/50
# 2563/2563 [==============================] - 111s 43ms/step - loss: 2.3704 - accuracy: 0.4626 - val_loss: 19.3924 - val_accuracy: 0.0779
# Epoch 49/50
# 2563/2563 [==============================] - 109s 43ms/step - loss: 2.3488 - accuracy: 0.4651 - val_loss: 19.7396 - val_accuracy: 0.0765
# Epoch 50/50
# 2563/2563 [==============================] - 108s 42ms/step - loss: 2.3244 - accuracy: 0.4687 - val_loss: 19.5658 - val_accuracy: 0.0757

# %%
def Predict_Words(model, tokenizer, text, n_word):
    result=text
    for _ in range(n_word):
        sequence = tokenizer.texts_to_sequences([text])
        sequence = np.array(sequence)
        preds = np.argmax(model.predict(sequence))
        predicted_word = ""

        for key, value in tokenizer.word_index.items():
            if value == preds:
                predicted_word = key
                break
        result+=" "+predicted_word
        # text=str(text)
        # text = text.split(" ")
        # text = text[-3:]
        # text+=" "+predicted_word

    return result

# %%
print(Predict_Words(model1, token, "I am a",1))
print(Predict_Words(model1, token, "dogs are ",1))
print(Predict_Words(model1, token, "I'm really grateful",3))
print(Predict_Words(model1, token, "human creativity in",2))
# Out:
# 1/1 [==============================] - 0s 28ms/step
# I am a very
# 1/1 [==============================] - 0s 27ms/step
# dogs are  livingston
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# I'm really grateful now and lot
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# human creativity in human world

# %%
print(Predict_Words(model1, token, "God please help",1))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# God please help that
